# %% [markdown]
# # Get hot keywords and draw chart
#
# Prepare for Django website

# %% [markdown]
# # Read top keywords from preprocessed file

# %%
import pandas as pd

# %%
df_data = pd.read_csv('cna_news_top200keywords_category_ws_pos.csv',sep=',')

# %%
df_data.head(12)
# Out:
#    category                                           top_keys
# 0        政治  [('台灣', 71), ('少年', 36), ('考試', 28), ('國際', 25...
# 1        科技  [('太空', 12), ('網路', 10), ('網站', 10), ('小行星', 1...
# 2        運動  [('聯盟', 21), ('球員', 16), ('賽季', 15), ('全壘打', 1...
# 3        證卷  [('台股', 36), ('指數', 32), ('台積電', 25), ('新台幣', ...
# 4        產經  [('台灣', 61), ('金管會', 56), ('市場', 31), ('基金', 3...
# 5        娛樂  [('媽媽', 16), ('電影', 16), ('節目', 15), ('紀曉君', 1...
# 6        生活  [('台灣', 38), ('疫苗', 25), ('電子', 22), ('教官', 17...
# 7        國際  [('俄羅斯', 55), ('日本', 33), ('烏克蘭', 32), ('美國', ...
# 8        社會  [('警方', 34), ('參選人', 22), ('選民', 21), ('林智堅', ...
# 9        文化  [('台灣', 56), ('文化', 32), ('電影', 20), ('藝術', 18...
# 10       兩岸  [('中國', 73), ('國家', 27), ('疫情', 26), ('政策', 26...
# 11       全部  [('台灣', 273), ('中國', 127), ('國家', 106), ('世界',...

# %%
# It is a string, not a list.
df_data['top_keys'][0]
# Out:
# "[('台灣', 71), ('少年', 36), ('考試', 28), ('國際', 25), ('國家', 23), ('蓬佩奧', 22), ('中國', 19), ('試題', 17), ('世界', 16), ('立法院', 15), ('條文', 15), ('疑義', 15), ('政策', 14), ('社會', 14), ('社宅', 14), ('中選會', 14), ('代表', 13), ('陳時中', 13), ('外交部', 12), ('美國', 12), ('政府', 12), ('民眾', 12), ('蘇貞昌', 12), ('產業', 12), ('全球', 12), ('警械', 12), ('警察', 12), ('司法', 12), ('法院', 12), ('公民', 12), ('林佳龍', 11), ('程序', 11), ('韓國', 11), ('人員', 11), ('憲法', 11), ('運動', 11), ('中心', 10), ('參選人', 10), ('副總統', 10), ('方式', 10), ('柯志恩', 10), ('系統', 9), ('黃偉哲', 9), ('總統', 9), ('法律', 9), ('高雄', 9), ('小組', 9), ('新聞稿', 9), ('應考人', 9), ('電視', 9), ('楊文科', 9), ('貿易', 8), ('台北', 8), ('問題', 8), ('民主', 8), ('條例', 8), ('簽證', 8), ('措施', 8), ('考選部', 8), ('空軍', 8), ('目標', 8), ('事件', 8), ('台商', 8), ('田中光', 7), ('天下', 7), ('電子', 7), ('區域', 7), ('聯合國', 7), ('大會', 7), ('國民黨', 7), ('力量', 7), ('鄭炳元', 7), ('台南', 7), ('朝野', 7), ('院會', 7), ('草案', 7), ('事項', 7), ('時間', 7), ('董事會', 7), ('直升機', 7), ('廠商', 6), ('電子報', 6), ('信箱', 6), ('格式', 6), ('關係', 6), ('媒體', 6), ('印太', 6), ('澳洲', 6), ('網路', 6), ('台海', 6), ('政見', 6), ('原則', 6), ('行政院', 6), ('會議', 6), ('時機', 6), ('考試院', 6), ('任務', 6), ('董事長', 6), ('鄭優', 6), ('津貼', 6), ('高雄市', 6), ('農會', 6), ('司法院', 6), ('戰機', 6), ('訓練', 6), ('竹北', 6), ('修正案', 6), ('吳釗燮', 6), ('規模', 5), ('戴維森', 5), ('武器', 5), ('資訊', 5), ('網民', 5), ('需求', 5), ('立委', 5), ('賴清德', 5), ('現場', 5), ('身體', 5), ('市長', 5), ('理由', 5), ('挑戰', 5), ('關鍵', 5), ('黨團', 5), ('警員', 5), ('內政部', 5), ('機關', 5), ('意見', 5), ('期限', 5), ('內容', 5), ('規定', 5), ('住宅', 5), ('台北市', 5), ('彭揚凱', 5), ('飛官', 5), ('黑鷹', 5), ('中華民國', 5), ('高考', 5), ('智慧', 4), ('經濟', 4), ('疫情', 4), ('實體', 4), ('經貿', 4), ('酒會', 4), ('日本', 4), ('空間', 4), ('組織', 4), ('民進黨', 4), ('新北', 4), ('人民', 4), ('選舉', 4), ('人士', 4), ('經驗', 4), ('聯盟', 4), ('共識', 4), ('致命性', 4), ('情境', 4), ('生命', 4), ('槍械', 4), ('民進黨團', 4), ('中央', 4), ('東南亞', 4), ('作業', 4), ('線上', 4), ('公民權', 4), ('社會局', 4), ('市府', 4), ('市民', 4), ('協會', 4), ('陳其邁', 4), ('刑事', 4), ('雷虎', 4), ('一級', 4), ('文官', 4), ('城區', 4), ('國民', 4), ('蔬菜', 4), ('期間', 4), ('童振源', 4), ('漁業展', 3), ('農業', 3), ('國內外', 3), ('聖文森', 3), ('印尼', 3), ('主任', 3), ('辦事處', 3), ('大使館', 3), ('國務卿', 3), ('主持人', 3), ('台灣人', 3), ('自由', 3), ('資源', 3), ('美方', 3), ('工具', 3), ('夥伴', 3), ('情勢', 3), ('共產黨', 3), ('行為', 3), ('現狀', 3), ('市政', 3), ('蔡英文', 3)]"

# %%
# Convert to list
eval(df_data['top_keys'][0])
# Out:
# [('台灣', 71),
#  ('少年', 36),
#  ('考試', 28),
#  ('國際', 25),
#  ('國家', 23),
#  ('蓬佩奧', 22),
#  ('中國', 19),
#  ('試題', 17),
#  ('世界', 16),
#  ('立法院', 15),
#  ('條文', 15),
#  ('疑義', 15),
#  ('政策', 14),
#  ('社會', 14),
#  ('社宅', 14),
#  ('中選會', 14),
#  ('代表', 13),
#  ('陳時中', 13),
#  ('外交部', 12),
#  ('美國', 12),
#  ('政府', 12),
#  ('民眾', 12),
#  ('蘇貞昌', 12),
#  ('產業', 12),
#  ('全球', 12),
#  ('警械', 12),
#  ('警察', 12),
#  ('司法', 12),
#  ('法院', 12),
#  ('公民', 12),
#  ('林佳龍', 11),
#  ('程序', 11),
#  ('韓國', 11),
#  ('人員', 11),
#  ('憲法', 11),
#  ('運動', 11),
#  ('中心', 10),
#  ('參選人', 10),
#  ('副總統', 10),
#  ('方式', 10),
#  ('柯志恩', 10),
#  ('系統', 9),
#  ('黃偉哲', 9),
#  ('總統', 9),
#  ('法律', 9),
#  ('高雄', 9),
#  ('小組', 9),
#  ('新聞稿', 9),
#  ('應考人', 9),
#  ('電視', 9),
#  ('楊文科', 9),
#  ('貿易', 8),
#  ('台北', 8),
#  ('問題', 8),
#  ('民主', 8),
#  ('條例', 8),
#  ('簽證', 8),
#  ('措施', 8),
#  ('考選部', 8),
#  ('空軍', 8),
#  ('目標', 8),
#  ('事件', 8),
#  ('台商', 8),
#  ('田中光', 7),
#  ('天下', 7),
#  ('電子', 7),
#  ('區域', 7),
#  ('聯合國', 7),
#  ('大會', 7),
#  ('國民黨', 7),
#  ('力量', 7),
#  ('鄭炳元', 7),
#  ('台南', 7),
#  ('朝野', 7),
#  ('院會', 7),
#  ('草案', 7),
#  ('事項', 7),
#  ('時間', 7),
#  ('董事會', 7),
#  ('直升機', 7),
#  ('廠商', 6),
#  ('電子報', 6),
#  ('信箱', 6),
#  ('格式', 6),
#  ('關係', 6),
#  ('媒體', 6),
#  ('印太', 6),
#  ('澳洲', 6),
#  ('網路', 6),
#  ('台海', 6),
#  ('政見', 6),
#  ('原則', 6),
#  ('行政院', 6),
#  ('會議', 6),
#  ('時機', 6),
#  ('考試院', 6),
#  ('任務', 6),
#  ('董事長', 6),
#  ('鄭優', 6),
#  ('津貼', 6),
#  ('高雄市', 6),
#  ('農會', 6),
#  ('司法院', 6),
#  ('戰機', 6),
#  ('訓練', 6),
#  ('竹北', 6),
#  ('修正案', 6),
#  ('吳釗燮', 6),
#  ('規模', 5),
#  ('戴維森', 5),
#  ('武器', 5),
#  ('資訊', 5),
#  ('網民', 5),
#  ('需求', 5),
#  ('立委', 5),
#  ('賴清德', 5),
#  ('現場', 5),
#  ('身體', 5),
#  ('市長', 5),
#  ('理由', 5),
#  ('挑戰', 5),
#  ('關鍵', 5),
#  ('黨團', 5),
#  ('警員', 5),
#  ('內政部', 5),
#  ('機關', 5),
#  ('意見', 5),
#  ('期限', 5),
#  ('內容', 5),
#  ('規定', 5),
#  ('住宅', 5),
#  ('台北市', 5),
#  ('彭揚凱', 5),
#  ('飛官', 5),
#  ('黑鷹', 5),
#  ('中華民國', 5),
#  ('高考', 5),
#  ('智慧', 4),
#  ('經濟', 4),
#  ('疫情', 4),
#  ('實體', 4),
#  ('經貿', 4),
#  ('酒會', 4),
#  ('日本', 4),
#  ('空間', 4),
#  ('組織', 4),
#  ('民進黨', 4),
#  ('新北', 4),
#  ('人民', 4),
#  ('選舉', 4),
#  ('人士', 4),
#  ('經驗', 4),
#  ('聯盟', 4),
#  ('共識', 4),
#  ('致命性', 4),
#  ('情境', 4),
#  ('生命', 4),
#  ('槍械', 4),
#  ('民進黨團', 4),
#  ('中央', 4),
#  ('東南亞', 4),
#  ('作業', 4),
#  ('線上', 4),
#  ('公民權', 4),
#  ('社會局', 4),
#  ('市府', 4),
#  ('市民', 4),
#  ('協會', 4),
#  ('陳其邁', 4),
#  ('刑事', 4),
#  ('雷虎', 4),
#  ('一級', 4),
#  ('文官', 4),
#  ('城區', 4),
#  ('國民', 4),
#  ('蔬菜', 4),
#  ('期間', 4),
#  ('童振源', 4),
#  ('漁業展', 3),
#  ('農業', 3),
#  ('國內外', 3),
#  ('聖文森', 3),
#  ('印尼', 3),
#  ('主任', 3),
#  ('辦事處', 3),
#  ('大使館', 3),
#  ('國務卿', 3),
#  ('主持人', 3),
#  ('台灣人', 3),
#  ('自由', 3),
#  ('資源', 3),
#  ('美方', 3),
#  ('工具', 3),
#  ('夥伴', 3),
#  ('情勢', 3),
#  ('共產黨', 3),
#  ('行為', 3),
#  ('現狀', 3),
#  ('市政', 3),
#  ('蔡英文', 3)]

# %% [markdown]
# # Store keywords in dict for user query

# %%
df_data.iterrows
# Out:
# <bound method DataFrame.iterrows of    category                                           top_keys
# 0        政治  [('台灣', 71), ('少年', 36), ('考試', 28), ('國際', 25...
# 1        科技  [('太空', 12), ('網路', 10), ('網站', 10), ('小行星', 1...
# 2        運動  [('聯盟', 21), ('球員', 16), ('賽季', 15), ('全壘打', 1...
# 3        證卷  [('台股', 36), ('指數', 32), ('台積電', 25), ('新台幣', ...
# 4        產經  [('台灣', 61), ('金管會', 56), ('市場', 31), ('基金', 3...
# 5        娛樂  [('媽媽', 16), ('電影', 16), ('節目', 15), ('紀曉君', 1...
# 6        生活  [('台灣', 38), ('疫苗', 25), ('電子', 22), ('教官', 17...
# 7        國際  [('俄羅斯', 55), ('日本', 33), ('烏克蘭', 32), ('美國', ...
# 8        社會  [('警方', 34), ('參選人', 22), ('選民', 21), ('林智堅', ...
# 9        文化  [('台灣', 56), ('文化', 32), ('電影', 20), ('藝術', 18...
# 10       兩岸  [('中國', 73), ('國家', 27), ('疫情', 26), ('政策', 26...
# 11       全部  [('台灣', 273), ('中國', 127), ('國家', 106), ('世界',...>

# %%
for idx, row in df_data.iterrows():
    print('---------idx--------------')
    print(idx)
    print('---------row--------------')    
    print(row)
# Out:
# ---------idx--------------
# 0
# ---------row--------------
# category                                                   政治
# top_keys    [('台灣', 71), ('少年', 36), ('考試', 28), ('國際', 25...
# Name: 0, dtype: object
# ---------idx--------------
# 1
# ---------row--------------
# category                                                   科技
# top_keys    [('太空', 12), ('網路', 10), ('網站', 10), ('小行星', 1...
# Name: 1, dtype: object
# ---------idx--------------
# 2
# ---------row--------------
# category                                                   運動
# top_keys    [('聯盟', 21), ('球員', 16), ('賽季', 15), ('全壘打', 1...
# Name: 2, dtype: object
# ---------idx--------------
# 3
# ---------row--------------
# category                                                   證卷
# top_keys    [('台股', 36), ('指數', 32), ('台積電', 25), ('新台幣', ...
# Name: 3, dtype: object
# ---------idx--------------
# 4
# ---------row--------------
# category                                                   產經
# top_keys    [('台灣', 61), ('金管會', 56), ('市場', 31), ('基金', 3...
# Name: 4, dtype: object
# ---------idx--------------
# 5
# ---------row--------------
# category                                                   娛樂
# top_keys    [('媽媽', 16), ('電影', 16), ('節目', 15), ('紀曉君', 1...
# Name: 5, dtype: object
# ---------idx--------------
# 6
# ---------row--------------
# category                                                   生活
# top_keys    [('台灣', 38), ('疫苗', 25), ('電子', 22), ('教官', 17...
# Name: 6, dtype: object
# ---------idx--------------
# 7
# ---------row--------------
# category                                                   國際
# top_keys    [('俄羅斯', 55), ('日本', 33), ('烏克蘭', 32), ('美國', ...
# Name: 7, dtype: object
# ---------idx--------------
# 8
# ---------row--------------
# category                                                   社會
# top_keys    [('警方', 34), ('參選人', 22), ('選民', 21), ('林智堅', ...
# Name: 8, dtype: object
# ---------idx--------------
# 9
# ---------row--------------
# category                                                   文化
# top_keys    [('台灣', 56), ('文化', 32), ('電影', 20), ('藝術', 18...
# Name: 9, dtype: object
# ---------idx--------------
# 10
# ---------row--------------
# category                                                   兩岸
# top_keys    [('中國', 73), ('國家', 27), ('疫情', 26), ('政策', 26...
# Name: 10, dtype: object
# ---------idx--------------
# 11
# ---------row--------------
# category                                                   全部
# top_keys    [('台灣', 273), ('中國', 127), ('國家', 106), ('世界',...
# Name: 11, dtype: object

# %%
data = {}
for idx, row in df_data.iterrows():
    data[row['category']] = eval(row['top_keys'])

# %%
data
# Out:
# {'政治': [('台灣', 71),
#   ('少年', 36),
#   ('考試', 28),
#   ('國際', 25),
#   ('國家', 23),
#   ('蓬佩奧', 22),
#   ('中國', 19),
#   ('試題', 17),
#   ('世界', 16),
#   ('立法院', 15),
#   ('條文', 15),
#   ('疑義', 15),
#   ('政策', 14),
#   ('社會', 14),
#   ('社宅', 14),
#   ('中選會', 14),
#   ('代表', 13),
#   ('陳時中', 13),
#   ('外交部', 12),
#   ('美國', 12),
#   ('政府', 12),
#   ('民眾', 12),
#   ('蘇貞昌', 12),
#   ('產業', 12),
#   ('全球', 12),
#   ('警械', 12),
#   ('警察', 12),
#   ('司法', 12),
#   ('法院', 12),
#   ('公民', 12),
#   ('林佳龍', 11),
#   ('程序', 11),
#   ('韓國', 11),
#   ('人員', 11),
#   ('憲法', 11),
#   ('運動', 11),
#   ('中心', 10),
#   ('參選人', 10),
#   ('副總統', 10),
#   ('方式', 10),
#   ('柯志恩', 10),
#   ('系統', 9),
#   ('黃偉哲', 9),
#   ('總統', 9),
#   ('法律', 9),
#   ('高雄', 9),
#   ('小組', 9),
#   ('新聞稿', 9),
#   ('應考人', 9),
#   ('電視', 9),
#   ('楊文科', 9),
#   ('貿易', 8),
#   ('台北', 8),
#   ('問題', 8),
#   ('民主', 8),
#   ('條例', 8),
#   ('簽證', 8),
#   ('措施', 8),
#   ('考選部', 8),
#   ('空軍', 8),
#   ('目標', 8),
#   ('事件', 8),
#   ('台商', 8),
#   ('田中光', 7),
#   ('天下', 7),
#   ('電子', 7),
#   ('區域', 7),
#   ('聯合國', 7),
#   ('大會', 7),
#   ('國民黨', 7),
#   ('力量', 7),
#   ('鄭炳元', 7),
#   ('台南', 7),
#   ('朝野', 7),
#   ('院會', 7),
#   ('草案', 7),
#   ('事項', 7),
#   ('時間', 7),
#   ('董事會', 7),
#   ('直升機', 7),
#   ('廠商', 6),
#   ('電子報', 6),
#   ('信箱', 6),
#   ('格式', 6),
#   ('關係', 6),
#   ('媒體', 6),
#   ('印太', 6),
#   ('澳洲', 6),
#   ('網路', 6),
#   ('台海', 6),
#   ('政見', 6),
#   ('原則', 6),
#   ('行政院', 6),
#   ('會議', 6),
#   ('時機', 6),
#   ('考試院', 6),
#   ('任務', 6),
#   ('董事長', 6),
#   ('鄭優', 6),
#   ('津貼', 6),
#   ('高雄市', 6),
#   ('農會', 6),
#   ('司法院', 6),
#   ('戰機', 6),
#   ('訓練', 6),
#   ('竹北', 6),
#   ('修正案', 6),
#   ('吳釗燮', 6),
#   ('規模', 5),
#   ('戴維森', 5),
#   ('武器', 5),
#   ('資訊', 5),
#   ('網民', 5),
#   ('需求', 5),
#   ('立委', 5),
#   ('賴清德', 5),
#   ('現場', 5),
#   ('身體', 5),
#   ('市長', 5),
#   ('理由', 5),
#   ('挑戰', 5),
#   ('關鍵', 5),
#   ('黨團', 5),
#   ('警員', 5),
#   ('內政部', 5),
#   ('機關', 5),
#   ('意見', 5),
#   ('期限', 5),
#   ('內容', 5),
#   ('規定', 5),
#   ('住宅', 5),
#   ('台北市', 5),
#   ('彭揚凱', 5),
#   ('飛官', 5),
#   ('黑鷹', 5),
#   ('中華民國', 5),
#   ('高考', 5),
#   ('智慧', 4),
#   ('經濟', 4),
#   ('疫情', 4),
#   ('實體', 4),
#   ('經貿', 4),
#   ('酒會', 4),
#   ('日本', 4),
#   ('空間', 4),
#   ('組織', 4),
#   ('民進黨', 4),
#   ('新北', 4),
#   ('人民', 4),
#   ('選舉', 4),
#   ('人士', 4),
#   ('經驗', 4),
#   ('聯盟', 4),
#   ('共識', 4),
#   ('致命性', 4),
#   ('情境', 4),
#   ('生命', 4),
#   ('槍械', 4),
#   ('民進黨團', 4),
#   ('中央', 4),
#   ('東南亞', 4),
#   ('作業', 4),
#   ('線上', 4),
#   ('公民權', 4),
#   ('社會局', 4),
#   ('市府', 4),
#   ('市民', 4),
#   ('協會', 4),
#   ('陳其邁', 4),
#   ('刑事', 4),
#   ('雷虎', 4),
#   ('一級', 4),
#   ('文官', 4),
#   ('城區', 4),
#   ('國民', 4),
#   ('蔬菜', 4),
#   ('期間', 4),
#   ('童振源', 4),
#   ('漁業展', 3),
#   ('農業', 3),
#   ('國內外', 3),
#   ('聖文森', 3),
#   ('印尼', 3),
#   ('主任', 3),
#   ('辦事處', 3),
#   ('大使館', 3),
#   ('國務卿', 3),
#   ('主持人', 3),
#   ('台灣人', 3),
#   ('自由', 3),
#   ('資源', 3),
#   ('美方', 3),
#   ('工具', 3),
#   ('夥伴', 3),
#   ('情勢', 3),
#   ('共產黨', 3),
#   ('行為', 3),
#   ('現狀', 3),
#   ('市政', 3),
#   ('蔡英文', 3)],
#  '科技': [('太空', 12),
#   ('網路', 10),
#   ('網站', 10),
#   ('小行星', 10),
#   ('國際', 9),
#   ('科技', 8),
#   ('太空站', 7),
#   ('民眾', 7),
#   ('趨勢', 7),
#   ('平台', 7),
#   ('行星', 7),
#   ('地球', 6),
#   ('指揮官', 6),
#   ('影音', 6),
#   ('帳號', 6),
#   ('克利斯托佛瑞提', 5),
#   ('女性', 5),
#   ('時間', 5),
#   ('內容', 5),
#   ('臉書', 5),
#   ('觀眾', 5),
#   ('數量', 5),
#   ('遊戲', 5),
#   ('衛星', 5),
#   ('歐洲', 4),
#   ('阿騰葉夫', 4),
#   ('總署', 4),
#   ('格式', 4),
#   ('電子', 4),
#   ('陷阱', 4),
#   ('玩家', 4),
#   ('影像', 4),
#   ('義大利', 3),
#   ('太空人', 3),
#   ('機會', 3),
#   ('任務', 3),
#   ('台灣', 3),
#   ('世界', 3),
#   ('電子報', 3),
#   ('天下', 3),
#   ('信箱', 3),
#   ('方式', 3),
#   ('訊息', 3),
#   ('集團', 3),
#   ('交易', 3),
#   ('迪莫弗斯', 3),
#   ('撞擊點', 3),
#   ('儀式', 2),
#   ('烏克蘭', 2),
#   ('軌道', 2),
#   ('紀錄', 2),
#   ('保持人', 2),
#   ('時期', 2),
#   ('美國', 2),
#   ('道路', 2),
#   ('公司', 2),
#   ('功能', 2),
#   ('資格', 2),
#   ('收益', 2),
#   ('新聞稿', 2),
#   ('資料', 2),
#   ('全球', 2),
#   ('資安', 2),
#   ('類型', 2),
#   ('洪偉淦', 2),
#   ('手法', 2),
#   ('金錢', 2),
#   ('個資', 2),
#   ('統計', 2),
#   ('市場', 2),
#   ('簡訊', 2),
#   ('錢財', 2),
#   ('寶物', 2),
#   ('國家', 2),
#   ('NASA', 2),
#   ('飛行器', 2),
#   ('碎片', 2),
#   ('畫面', 2),
#   ('科學家', 2),
#   ('周圍', 2),
#   ('科學', 2),
#   ('團隊', 2),
#   ('現場', 1),
#   ('首位', 1),
#   ('指揮權', 1),
#   ('法新社', 1),
#   ('指揮棒', 1),
#   ('俄籍', 1),
#   ('戰事', 1),
#   ('金色', 1),
#   ('鑰匙', 1),
#   ('克利斯托佛瑞提曾', 1),
#   ('空軍', 1),
#   ('飛行員', 1),
#   ('美國籍', 1),
#   ('網頁', 1),
#   ('美國人', 1),
#   ('俄羅斯人', 1),
#   ('阿波羅', 1),
#   ('聯合號', 1),
#   ('計畫', 1),
#   ('冷戰', 1),
#   ('蘇聯', 1),
#   ('關係', 1),
#   ('戰爭', 1),
#   ('人員', 1),
#   ('情況', 1),
#   ('地面', 1),
#   ('中心', 1),
#   ('指示', 1),
#   ('決定', 1),
#   ('抖音', 1),
#   ('影片', 1),
#   ('旗下', 1),
#   ('好評', 1),
#   ('用戶點', 1),
#   ('擊臉書', 1),
#   ('欄位', 1),
#   ('短秒數', 1),
#   ('版位', 1),
#   ('動態牆', 1),
#   ('社團', 1),
#   ('工具', 1),
#   ('星星', 1),
#   ('留言', 1),
#   ('業者', 1),
#   ('指標性', 1),
#   ('台灣區', 1),
#   ('香港區', 1),
#   ('總經理', 1),
#   ('習慣', 1),
#   ('話題', 1),
#   ('速度', 1),
#   ('想像', 1),
#   ('損失', 1),
#   ('影響', 1),
#   ('層面', 1),
#   ('全家', 1),
#   ('大小', 1),
#   ('成員', 1),
#   ('生活', 1),
#   ('整體', 1),
#   ('氛圍', 1),
#   ('總數', 1),
#   ('經濟', 1),
#   ('商機', 1),
#   ('吸引力', 1),
#   ('產品', 1),
#   ('圖片', 1),
#   ('價格', 1),
#   ('消費', 1),
#   ('人頭', 1),
#   ('網拍', 1),
#   ('冤大頭', 1),
#   ('特徵', 1),
#   ('售價', 1),
#   ('行情', 1),
#   ('網址', 1),
#   ('意義', 1),
#   ('地址', 1),
#   ('電話', 1),
#   ('銀行', 1),
#   ('管道', 1),
#   ('群組', 1),
#   ('股票', 1),
#   ('理由', 1),
#   ('代幣', 1),
#   ('駭客', 1),
#   ('貨幣', 1),
#   ('角色', 1),
#   ('裝備', 1),
#   ('點數', 1),
#   ('儲值金', 1),
#   ('限制', 1),
#   ('話術', 1),
#   ('身分', 1),
#   ('官方', 1),
#   ('郵件', 1),
#   ('問題', 1),
#   ('消費者', 1),
#   ('信用卡', 1),
#   ('供應鏈', 1),
#   ('中樞', 1),
#   ('航空', 1),
#   ('近距離', 1),
#   ('大型', 1),
#   ('岩石', 1),
#   ('太空船', 1),
#   ('機制', 1),
#   ('目標', 1),
#   ('期間', 1),
#   ('輕型', 1),
#   ('立方體', 1),
#   ('角度', 1),
#   ('經過', 1),
#   ('距離', 1),
#   ('雙相機', 1),
#   ('系統', 1),
#   ('證據', 1),
#   ('時速', 1)],
#  '運動': [('聯盟', 21),
#   ('球員', 16),
#   ('賽季', 15),
#   ('全壘打', 14),
#   ('賈吉', 14),
#   ('比賽', 13),
#   ('美聯', 13),
#   ('台灣', 12),
#   ('王柏融', 12),
#   ('安打', 11),
#   ('球隊', 11),
#   ('黃暐傑', 11),
#   ('職棒', 9),
#   ('卡達', 9),
#   ('洋基', 9),
#   ('球迷', 8),
#   ('中信', 8),
#   ('兄弟隊', 8),
#   ('谷毛唯嘉', 8),
#   ('歐洲', 8),
#   ('陳偉殷', 8),
#   ('林岳平', 7),
#   ('賽事', 7),
#   ('獵鷹', 7),
#   ('藍鳥', 7),
#   ('紀錄', 7),
#   ('病毒', 6),
#   ('一軍', 6),
#   ('兄弟', 6),
#   ('世足賽', 6),
#   ('足球', 6),
#   ('世界', 6),
#   ('職業', 6),
#   ('火腿', 6),
#   ('吉力吉撈', 5),
#   ('獅隊', 5),
#   ('龍隊', 5),
#   ('投手', 5),
#   ('洋投', 5),
#   ('桃猿隊', 5),
#   ('王偉祥', 5),
#   ('新台幣', 5),
#   ('季後賽', 5),
#   ('曾文鼎', 5),
#   ('記者會', 5),
#   ('特攻', 5),
#   ('台鋼', 5),
#   ('時間', 5),
#   ('例行賽', 5),
#   ('3A', 5),
#   ('影片', 4),
#   ('中華', 4),
#   ('鞏冠', 4),
#   ('COVID-19', 4),
#   ('冠狀', 4),
#   ('疾病', 4),
#   ('打點', 4),
#   ('世足', 4),
#   ('郭嚴文', 4),
#   ('生涯', 4),
#   ('目標', 4),
#   ('新人王', 4),
#   ('宇宙', 4),
#   ('棒球', 4),
#   ('打擊率', 4),
#   ('成本', 4),
#   ('美國', 4),
#   ('經典賽', 4),
#   ('馬瑞斯', 4),
#   ('味全龍', 3),
#   ('主場', 3),
#   ('胡智為', 3),
#   ('中繼', 3),
#   ('二壘', 3),
#   ('比分', 3),
#   ('王維中', 3),
#   ('對手', 3),
#   ('陰性', 3),
#   ('法新社', 3),
#   ('疫情', 3),
#   ('國際', 3),
#   ('總會', 3),
#   ('衛生部', 3),
#   ('球團', 3),
#   ('德保拉', 3),
#   ('豪勁', 3),
#   ('觸身球', 3),
#   ('進度', 3),
#   ('高爾夫', 3),
#   ('邀請賽', 3),
#   ('柏忌', 3),
#   ('標準', 3),
#   ('優勢', 3),
#   ('球場', 3),
#   ('機會', 3),
#   ('總經理', 3),
#   ('劉志威', 3),
#   ('運彩', 3),
#   ('中鋒', 3),
#   ('名單', 3),
#   ('籃球', 3),
#   ('合約', 3),
#   ('總教練', 3),
#   ('劉孟竹', 3),
#   ('張樹人', 3),
#   ('日本', 3),
#   ('打擊', 3),
#   ('聯賽', 3),
#   ('傷兵', 3),
#   ('足壇', 3),
#   ('英超', 3),
#   ('近況', 3),
#   ('肩膀', 3),
#   ('教練', 3),
#   ('重砲', 3),
#   ('運動家隊', 3),
#   ('來源', 2),
#   ('單場', 2),
#   ('統一獅', 2),
#   ('台南', 2),
#   ('棒球場', 2),
#   ('年度', 2),
#   ('勝率', 2),
#   ('李凱威', 2),
#   ('攻勢', 2),
#   ('陽春砲', 2),
#   ('新高', 2),
#   ('敗投', 2),
#   ('MVP', 2),
#   ('當局', 2),
#   ('世界盃', 2),
#   ('小時', 2),
#   ('結果', 2),
#   ('會內賽', 2),
#   ('體育', 2),
#   ('準則', 2),
#   ('隊史', 2),
#   ('危機', 2),
#   ('陳文杰', 2),
#   ('蔡齊哲', 2),
#   ('僵局', 2),
#   ('隊友', 2),
#   ('出局數', 2),
#   ('好手', 2),
#   ('名人賽', 2),
#   ('三商杯', 2),
#   ('回合', 2),
#   ('鐵桿', 2),
#   ('準度', 2),
#   ('洪健堯', 2),
#   ('選手', 2),
#   ('本土', 2),
#   ('控衛', 2),
#   ('新秀', 2),
#   ('蔣淯安', 2),
#   ('時期', 2),
#   ('電子報', 2),
#   ('天下', 2),
#   ('電子', 2),
#   ('信箱', 2),
#   ('格式', 2),
#   ('動力', 2),
#   ('體育台', 2),
#   ('方式', 2),
#   ('蔡尚樺', 2),
#   ('方向', 2),
#   ('秘書長', 2),
#   ('千葉羅德', 2),
#   ('海洋隊', 2),
#   ('打數', 2),
#   ('二軍', 2),
#   ('日職', 2),
#   ('客場', 2),
#   ('賽程', 2),
#   ('豪頓', 2),
#   ('研究', 2),
#   ('歐國聯', 2),
#   ('臉書', 2),
#   ('左投', 2),
#   ('阪神虎隊', 2),
#   ('台灣隊', 2),
#   ('教練團', 2),
#   ('會議', 2),
#   ('大聯盟', 2),
#   ('紐約', 2),
#   ('多倫多', 2),
#   ('觀眾', 2),
#   ('左外野', 2),
#   ('牛棚', 2),
#   ('打席', 2),
#   ('巨人隊', 2),
#   ('打者', 2),
#   ('勝差', 1),
#   ('。獅隊', 1),
#   ('亂流', 1),
#   ('先鋒', 1),
#   ('跑者', 1),
#   ('味全龍隊', 1),
#   ('大局', 1),
#   ('。龍隊', 1)],
#  '證卷': [('台股', 36),
#   ('指數', 32),
#   ('台積電', 25),
#   ('新台幣', 23),
#   ('外資', 21),
#   ('投信', 17),
#   ('股價', 16),
#   ('股市', 15),
#   ('終場', 15),
#   ('淨值', 15),
#   ('電子', 13),
#   ('法人', 13),
#   ('漲幅', 12),
#   ('潤泰', 12),
#   ('美國', 11),
#   ('美股', 11),
#   ('個股', 10),
#   ('公司', 10),
#   ('尾盤', 10),
#   ('金融', 10),
#   ('營收', 9),
#   ('台泥', 9),
#   ('容逸燊', 9),
#   ('央行', 9),
#   ('客戶', 9),
#   ('鴻海', 8),
#   ('市值', 8),
#   ('期貨', 8),
#   ('台灣', 7),
#   ('交易日', 7),
#   ('世界', 7),
#   ('強彈', 7),
#   ('英國', 7),
#   ('金管會', 7),
#   ('早盤', 7),
#   ('跌幅', 7),
#   ('市場', 6),
#   ('壓力', 6),
#   ('投資人', 6),
#   ('走勢', 6),
#   ('電子股', 6),
#   ('金融股', 6),
#   ('自營商', 6),
#   ('證券', 6),
#   ('危機', 6),
#   ('短線', 6),
#   ('匯率', 6),
#   ('交易', 6),
#   ('財報', 6),
#   ('力積電', 6),
#   ('人壽', 6),
#   ('張振山', 6),
#   ('時間', 5),
#   ('半導體', 5),
#   ('成交值', 5),
#   ('航運', 5),
#   ('陸資', 5),
#   ('動向', 5),
#   ('交易所', 5),
#   ('單位', 5),
#   ('需求', 5),
#   ('銀行', 5),
#   ('債市', 5),
#   ('新低', 5),
#   ('如興', 5),
#   ('股東', 5),
#   ('價差', 5),
#   ('現貨', 5),
#   ('南山', 5),
#   ('現金', 5),
#   ('道瓊', 4),
#   ('那斯達克', 4),
#   ('幅度', 4),
#   ('年增', 4),
#   ('規模', 4),
#   ('新高', 4),
#   ('政策', 4),
#   ('興櫃', 4),
#   ('關係', 4),
#   ('業務', 4),
#   ('經濟', 4),
#   ('英格蘭', 4),
#   ('聯準會', 4),
#   ('賣壓', 4),
#   ('中小型股', 4),
#   ('董事', 4),
#   ('情況', 4),
#   ('大盤', 4),
#   ('潤泰全', 4),
#   ('會議', 4),
#   ('殖利率', 3),
#   ('奇摩', 3),
#   ('爆紅台', 3),
#   ('股榜', 3),
#   ('企業', 3),
#   ('產業', 3),
#   ('訂單', 3),
#   ('華新', 3),
#   ('副總經理', 3),
#   ('美元', 3),
#   ('程曦', 3),
#   ('國內', 3),
#   ('電子報', 3),
#   ('天下', 3),
#   ('信箱', 3),
#   ('格式', 3),
#   ('晶圓', 3),
#   ('行情', 3),
#   ('會計師', 3),
#   ('事務所', 3),
#   ('國際', 3),
#   ('台北', 3),
#   ('電子期', 3),
#   ('收盤價', 3),
#   ('價格', 3),
#   ('張數', 3),
#   ('櫃買', 3),
#   ('投控', 3),
#   ('基本面', 3),
#   ('新股', 3),
#   ('海外', 3),
#   ('公債', 2),
#   ('族群', 2),
#   ('產品', 2),
#   ('胡連', 2),
#   ('類股', 2),
#   ('歷史', 2),
#   ('加計盤', 2),
#   ('統計', 2),
#   ('中信金', 2),
#   ('中央社', 2),
#   ('記者', 2),
#   ('情緒', 2),
#   ('日本', 2),
#   ('全球', 2),
#   ('買盤', 2),
#   ('經驗', 2),
#   ('金控', 2),
#   ('投信連', 2),
#   ('戰略', 2),
#   ('新板', 2),
#   ('漲跌', 2),
#   ('顧客', 2),
#   ('整體', 2),
#   ('民眾', 2),
#   ('合約', 2),
#   ('後市', 2),
#   ('重點', 2),
#   ('龍頭', 2),
#   ('低點', 2),
#   ('機率', 2),
#   ('言論', 2),
#   ('臨時會', 2),
#   ('董事長', 2),
#   ('張水江', 2),
#   ('財務', 2),
#   ('陳怡如', 2),
#   ('媒體', 2),
#   ('基金', 2),
#   ('法律', 2),
#   ('持股', 2),
#   ('金融期', 2),
#   ('期交所', 2),
#   ('金額', 2),
#   ('權值股', 2),
#   ('聯發科', 2),
#   ('聯電', 2),
#   ('日月光', 2),
#   ('航運股', 2),
#   ('長榮', 2),
#   ('平盤', 2),
#   ('吳繼先', 2),
#   ('預期', 2),
#   ('強勢', 2),
#   ('階段', 2),
#   ('面板', 2),
#   ('變化', 2),
#   ('潤泰新', 2),
#   ('比例', 2),
#   ('信用', 2),
#   ('年增率', 2),
#   ('收益', 2),
#   ('F4', 2),
#   ('股期市', 2),
#   ('憑證', 2),
#   ('股權', 2),
#   ('工業', 1),
#   ('標準', 1),
#   ('普爾', 1),
#   ('次數', 1),
#   ('瀏覽量', 1),
#   ('季增', 1),
#   ('爆紅台股榜', 1),
#   ('，元', 1),
#   ('宇宙', 1),
#   ('概念股', 1),
#   ('威盛', 1),
#   ('集團', 1),
#   ('宏達電', 1),
#   ('車用', 1)],
#  '產經': [('台灣', 61),
#   ('金管會', 56),
#   ('市場', 31),
#   ('基金', 31),
#   ('金融', 22),
#   ('技術', 19),
#   ('新台幣', 19),
#   ('曝險', 19),
#   ('銀行', 18),
#   ('國家', 18),
#   ('業者', 17),
#   ('員工', 16),
#   ('英國', 16),
#   ('越南', 16),
#   ('產品', 14),
#   ('晶片', 14),
#   ('民眾', 13),
#   ('會議', 13),
#   ('統計', 12),
#   ('經濟', 12),
#   ('推案量', 12),
#   ('莫德納', 11),
#   ('華航', 11),
#   ('專區', 11),
#   ('政府', 11),
#   ('世界', 10),
#   ('電子', 10),
#   ('客機', 10),
#   ('風險', 10),
#   ('措施', 10),
#   ('國科會', 10),
#   ('電信', 10),
#   ('公司', 9),
#   ('產業', 9),
#   ('資訊', 9),
#   ('企業', 9),
#   ('預算', 9),
#   ('央行', 9),
#   ('年增', 9),
#   ('李宜真', 8),
#   ('新聞稿', 8),
#   ('疫情', 8),
#   ('電子報', 8),
#   ('天下', 8),
#   ('信箱', 8),
#   ('格式', 8),
#   ('國際', 8),
#   ('證券', 8),
#   ('政策', 8),
#   ('張子敏', 8),
#   ('福利', 8),
#   ('核心', 8),
#   ('關鍵', 8),
#   ('半導體', 8),
#   ('官員', 8),
#   ('記者會', 8),
#   ('電競', 8),
#   ('液晶', 8),
#   ('軟體', 8),
#   ('競爭', 8),
#   ('全球', 7),
#   ('債券', 7),
#   ('規範', 7),
#   ('公會', 7),
#   ('機制', 7),
#   ('方式', 7),
#   ('保險業', 7),
#   ('顯示器', 7),
#   ('美元', 7),
#   ('雲端', 7),
#   ('大哥大', 7),
#   ('頻段', 7),
#   ('唐邦正', 7),
#   ('比率', 6),
#   ('金額', 6),
#   ('制度', 6),
#   ('意見', 6),
#   ('財政', 6),
#   ('中央', 6),
#   ('稅收', 6),
#   ('債務', 6),
#   ('成長率', 6),
#   ('整體', 6),
#   ('海外', 6),
#   ('客戶', 6),
#   ('總局', 6),
#   ('指數', 6),
#   ('平台', 6),
#   ('問題', 6),
#   ('中國', 6),
#   ('不鏽鋼', 6),
#   ('合併案', 6),
#   ('西門子', 6),
#   ('聯電', 6),
#   ('總經理', 5),
#   ('商業', 5),
#   ('科技', 5),
#   ('美國', 5),
#   ('波音', 5),
#   ('成本', 5),
#   ('環境', 5),
#   ('副局長', 5),
#   ('個股', 5),
#   ('階段', 5),
#   ('計畫', 5),
#   ('集團', 5),
#   ('架構', 5),
#   ('代表', 5),
#   ('委員', 5),
#   ('委員會', 5),
#   ('供應鏈', 5),
#   ('財政部', 5),
#   ('情事', 5),
#   ('數字', 5),
#   ('集邦', 5),
#   ('通膨', 5),
#   ('需求', 5),
#   ('時間', 5),
#   ('資源', 5),
#   ('國內', 5),
#   ('工業', 5),
#   ('聯盟', 5),
#   ('楊金龍', 5),
#   ('價格', 5),
#   ('低資費', 5),
#   ('頻譜', 5),
#   ('住展', 5),
#   ('散裝船', 5),
#   ('有限公司', 4),
#   ('類型', 4),
#   ('疾病', 4),
#   ('機構', 4),
#   ('方案', 4),
#   ('網路', 4),
#   ('觀測站', 4),
#   ('草案', 4),
#   ('等級', 4),
#   ('目標', 4),
#   ('指標', 4),
#   ('證期局', 4),
#   ('規模', 4),
#   ('證交所', 4),
#   ('金控', 4),
#   ('金融業', 4),
#   ('持股', 4),
#   ('莊琇媛', 4),
#   ('程序', 4),
#   ('辦法', 4),
#   ('立法院', 4),
#   ('法規', 4),
#   ('缺口', 4),
#   ('年度', 4),
#   ('歲入', 4),
#   ('稅課', 4),
#   ('收入', 4),
#   ('資料', 4),
#   ('數據', 4),
#   ('歐洲', 4),
#   ('消費者', 4),
#   ('原因', 4),
#   ('面板', 4),
#   ('金融防', 4),
#   ('期貨', 4),
#   ('案例', 4),
#   ('方面', 4),
#   ('議題', 4),
#   ('韓國', 4),
#   ('利益', 4),
#   ('股價', 4),
#   ('台股', 4),
#   ('外匯', 4),
#   ('房市', 4),
#   ('燁聯', 4),
#   ('鋼廠', 4),
#   ('供給量', 4),
#   ('產業署', 4),
#   ('系統', 4),
#   ('聽證會', 4),
#   ('副總經理', 4),
#   ('何世昌', 4),
#   ('船舶', 4),
#   ('中航', 4),
#   ('鐵礦砂', 4),
#   ('設計', 4),
#   ('股份', 3),
#   ('業務', 3),
#   ('日本', 3),
#   ('澳洲', 3),
#   ('子公司', 3),
#   ('COVID-19', 3),
#   ('角色', 3),
#   ('行銷', 3),
#   ('策略', 3),
#   ('能力', 3),
#   ('訂單', 3),
#   ('說明書', 3),
#   ('收益', 3),
#   ('家數', 3),
#   ('時程', 3),
#   ('部門', 3)],
#  '娛樂': [('媽媽', 16),
#   ('電影', 16),
#   ('節目', 15),
#   ('紀曉君', 14),
#   ('角色', 13),
#   ('戰爭', 10),
#   ('老師', 9),
#   ('許瑋甯', 9),
#   ('市場', 8),
#   ('公司', 7),
#   ('廖家儀', 7),
#   ('豪門', 7),
#   ('袁惟仁', 7),
#   ('吳慷仁', 7),
#   ('姚坤君', 6),
#   ('陳文茜', 6),
#   ('台東', 5),
#   ('歌曲', 5),
#   ('台灣', 5),
#   ('世界', 5),
#   ('林煥鈞', 5),
#   ('活動', 5),
#   ('澤倫斯基', 5),
#   ('烏克蘭', 5),
#   ('酷力歐', 5),
#   ('演員', 4),
#   ('月亮', 4),
#   ('媒體', 4),
#   ('女兒', 4),
#   ('孩子', 4),
#   ('公視', 4),
#   ('金馬', 4),
#   ('執委會', 4),
#   ('窄路', 4),
#   ('微塵', 4),
#   ('羅巧倫', 4),
#   ('陳仙梅', 4),
#   ('內容', 4),
#   ('事業', 4),
#   ('人氣', 4),
#   ('戲劇', 4),
#   ('遊戲', 4),
#   ('票數', 4),
#   ('臉書', 4),
#   ('總統', 4),
#   ('社會', 4),
#   ('記者', 4),
#   ('酷力', 4),
#   ('歌手', 3),
#   ('導演', 3),
#   ('王小棣', 3),
#   ('小棣', 3),
#   ('生活', 3),
#   ('名單', 3),
#   ('主角', 3),
#   ('系列', 3),
#   ('阿斯頓', 3),
#   ('馬丁', 3),
#   ('女星', 3),
#   ('豬腳', 3),
#   ('老公', 3),
#   ('電子報', 3),
#   ('天下', 3),
#   ('電子', 3),
#   ('信箱', 3),
#   ('格式', 3),
#   ('成員', 3),
#   ('粉絲', 3),
#   ('藝人', 3),
#   ('電視', 3),
#   ('典禮', 3),
#   ('喜劇', 3),
#   ('俄烏', 3),
#   ('長期', 3),
#   ('網友', 3),
#   ('小胖', 3),
#   ('功課', 2),
#   ('張耀仁', 2),
#   ('支票', 2),
#   ('胡德夫', 2),
#   ('大學', 2),
#   ('家人', 2),
#   ('劇情', 2),
#   ('挑戰', 2),
#   ('金馬獎', 2),
#   ('規定', 2),
#   ('香港', 2),
#   ('佳士得', 2),
#   ('跑車', 2),
#   ('法新社', 2),
#   ('物件', 2),
#   ('八點檔', 2),
#   ('市井', 2),
#   ('現實', 2),
#   ('國中', 2),
#   ('水餃', 2),
#   ('黃雪琴', 2),
#   ('觀眾', 2),
#   ('選秀', 2),
#   ('原子', 2),
#   ('少年', 2),
#   ('心聲', 2),
#   ('林佳辰', 2),
#   ('周子翔', 2),
#   ('李哲言', 2),
#   ('人物', 2),
#   ('行為', 2),
#   ('金鐘獎', 2),
#   ('民眾', 2),
#   ('火神', 2),
#   ('眼淚', 2),
#   ('初選', 2),
#   ('作品', 2),
#   ('決選', 2),
#   ('過程', 2),
#   ('風險', 2),
#   ('軍隊', 2),
#   ('安多利', 2),
#   ('影片', 2),
#   ('生命', 2),
#   ('辦法', 2),
#   ('訊息', 2),
#   ('情況', 2),
#   ('敏迪', 2),
#   ('合照', 2),
#   ('紀寶如', 2),
#   ('當地', 2),
#   ('老家', 2),
#   ('蔡琴', 2),
#   ('同事', 2),
#   ('狀態', 2),
#   ('林晨曦', 2),
#   ('高中', 2),
#   ('賈靜雯', 2),
#   ('戲碼', 2),
#   ('肢體', 2),
#   ('波希', 2),
#   ('友人', 2),
#   ('加州', 2),
#   ('葛萊美獎', 2),
#   ('專輯', 2),
#   ('茁劇場', 1),
#   ('情侶', 1),
#   ('冤家', 1),
#   ('曝戲', 1),
#   ('葛盈瑄', 1),
#   ('母親', 1),
#   ('茶館', 1),
#   ('茶錢', 1),
#   ('服務生', 1),
#   ('燒酒雞', 1),
#   ('貴客', 1),
#   ('表舅', 1),
#   ('叔公', 1),
#   ('現場', 1),
#   ('淡江', 1),
#   ('心防', 1),
#   ('畫面', 1),
#   ('台詞', 1),
#   ('做法', 1),
#   ('名常', 1),
#   ('兒子', 1),
#   ('天兵', 1),
#   ('面前', 1),
#   ('神經', 1),
#   ('要求', 1),
#   ('台視', 1),
#   ('中華', 1),
#   ('電信', 1),
#   ('官網', 1),
#   ('範疇', 1),
#   ('資格', 1),
#   ('張繼聰', 1),
#   ('袁澧林', 1),
#   ('黃衍仁', 1),
#   ('音樂', 1),
#   ('生死', 1),
#   ('複製品', 1),
#   ('價格', 1),
#   ('拍賣會', 1),
#   ('上述', 1),
#   ('所得', 1),
#   ('新台幣', 1),
#   ('進款', 1),
#   ('DB5', 1),
#   ('大燈', 1),
#   ('機槍', 1),
#   ('道具', 1),
#   ('英國', 1),
#   ('特技車', 1),
#   ('汽車', 1),
#   ('服裝', 1),
#   ('配件', 1),
#   ('民視', 1),
#   ('小販', 1),
#   ('長疤', 1),
#   ('情同', 1),
#   ('姐妹', 1),
#   ('同學', 1),
#   ('命運', 1)],
#  '生活': [('台灣', 38),
#   ('疫苗', 25),
#   ('電子', 22),
#   ('教官', 17),
#   ('業者', 16),
#   ('民眾', 15),
#   ('信箱', 13),
#   ('公司', 12),
#   ('疫情', 12),
#   ('學校', 12),
#   ('號碼', 12),
#   ('發票', 11),
#   ('台北', 10),
#   ('中心', 9),
#   ('交通部', 9),
#   ('世界', 9),
#   ('政府', 9),
#   ('航空', 9),
#   ('子宮頸癌', 9),
#   ('學生', 9),
#   ('鄭英傑', 9),
#   ('遠通', 9),
#   ('桃機', 8),
#   ('旅客', 8),
#   ('措施', 8),
#   ('國際', 8),
#   ('電子報', 8),
#   ('天下', 8),
#   ('格式', 8),
#   ('事項', 8),
#   ('美國', 8),
#   ('遠洋', 8),
#   ('漁業', 8),
#   ('氣象局', 8),
#   ('機場', 7),
#   ('結果', 7),
#   ('獎金', 7),
#   ('新加坡', 7),
#   ('時間', 7),
#   ('台南', 7),
#   ('校園', 7),
#   ('黃恩鴻', 7),
#   ('電商', 7),
#   ('星宇', 7),
#   ('設施', 6),
#   ('邊境', 6),
#   ('階段', 6),
#   ('新台幣', 6),
#   ('方式', 6),
#   ('派彩', 6),
#   ('獎號', 6),
#   ('台彩', 6),
#   ('辦事處', 6),
#   ('嘉義', 6),
#   ('生活', 6),
#   ('資料', 6),
#   ('特教', 6),
#   ('電收', 6),
#   ('雲端', 6),
#   ('郵件', 6),
#   ('國稅局', 6),
#   ('手機', 6),
#   ('人員', 5),
#   ('范孝倫', 5),
#   ('作業', 5),
#   ('人次', 5),
#   ('觀光局', 5),
#   ('病毒', 5),
#   ('中央社', 5),
#   ('五分車', 5),
#   ('清單', 5),
#   ('新聞稿', 5),
#   ('澎湖', 5),
#   ('體溫', 5),
#   ('天氣', 5),
#   ('夕陽', 5),
#   ('街道', 5),
#   ('高溫', 5),
#   ('校車', 5),
#   ('通知', 5),
#   ('地區', 5),
#   ('航機', 5),
#   ('居家', 4),
#   ('動線', 4),
#   ('商業', 4),
#   ('總經理', 4),
#   ('工程', 4),
#   ('政策', 4),
#   ('期間', 4),
#   ('星彩', 4),
#   ('記者', 4),
#   ('特色', 4),
#   ('漁獲', 4),
#   ('漁業署', 4),
#   ('人權', 4),
#   ('行動', 4),
#   ('權益', 4),
#   ('病變', 4),
#   ('航線', 4),
#   ('台南市', 4),
#   ('遊客', 4),
#   ('柯建銘', 4),
#   ('工作', 4),
#   ('中央', 4),
#   ('接種率', 4),
#   ('嬰幼兒', 4),
#   ('氣象', 4),
#   ('位置', 4),
#   ('交通', 4),
#   ('高雄市', 4),
#   ('張永昌', 4),
#   ('領袖', 4),
#   ('載具', 4),
#   ('財政部', 4),
#   ('平台', 4),
#   ('衛福部', 3),
#   ('桃園', 3),
#   ('單位', 3),
#   ('國境', 3),
#   ('計程車', 3),
#   ('司機', 3),
#   ('規定', 3),
#   ('師生', 3),
#   ('頭獎', 3),
#   ('貳獎', 3),
#   ('馬來西亞', 3),
#   ('細節', 3),
#   ('冠狀', 3),
#   ('疾病', 3),
#   ('周士弼', 3),
#   ('高雄', 3),
#   ('蒜頭', 3),
#   ('糖廠', 3),
#   ('台糖', 3),
#   ('情形', 3),
#   ('路線', 3),
#   ('勞工部', 3),
#   ('童工', 3),
#   ('貨品', 3),
#   ('計畫', 3),
#   ('船員', 3),
#   ('全球', 3),
#   ('企業', 3),
#   ('社會', 3),
#   ('影響', 3),
#   ('機制', 3),
#   ('部會', 3),
#   ('COVID-19', 3),
#   ('抹片', 3),
#   ('數據', 3),
#   ('癌症', 3),
#   ('麗娜輪', 3),
#   ('航港局', 3),
#   ('馬公港', 3),
#   ('郭貞慧', 3),
#   ('教育部', 3),
#   ('大專', 3),
#   ('吳林輝', 3),
#   ('部隊', 3),
#   ('王必勝', 3),
#   ('莫德納', 3),
#   ('世代', 3),
#   ('西區', 3),
#   ('機會', 3),
#   ('台東', 3),
#   ('溫差', 3),
#   ('駕駛', 3),
#   ('特教生', 3),
#   ('國道', 3),
#   ('智慧', 3),
#   ('評審團', 3),
#   ('勞務', 3),
#   ('統一發票', 3),
#   ('東北', 3),
#   ('陣雨', 3),
#   ('海面', 3),
#   ('設計', 3),
#   ('殼套組', 3),
#   ('狀況', 2),
#   ('金額', 2),
#   ('蘇貞昌', 2),
#   ('人數', 2),
#   ('商店', 2),
#   ('周邊', 2),
#   ('正彩', 2),
#   ('威力彩', 2),
#   ('症狀', 2),
#   ('主任', 2),
#   ('鄭智鴻', 2),
#   ('消費者', 2),
#   ('行程', 2),
#   ('方案', 2),
#   ('意願', 2),
#   ('吉隆坡', 2),
#   ('產品', 2),
#   ('音樂', 2),
#   ('旅展', 2),
#   ('台灣館', 2),
#   ('雙鐵', 2),
#   ('高鐵站', 2)],
#  '國際': [('俄羅斯', 55),
#   ('日本', 33),
#   ('烏克蘭', 32),
#   ('美國', 31),
#   ('北溪', 30),
#   ('管線', 30),
#   ('德國', 28),
#   ('飛彈', 27),
#   ('中國', 27),
#   ('芬蘭', 26),
#   ('北韓', 24),
#   ('國家', 23),
#   ('英國', 23),
#   ('戰機', 22),
#   ('天然氣', 20),
#   ('俄國', 20),
#   ('政府', 18),
#   ('南韓', 16),
#   ('推特', 16),
#   ('國際', 15),
#   ('歐洲', 15),
#   ('伊朗', 15),
#   ('歐盟', 13),
#   ('空軍', 13),
#   ('喇嘛', 12),
#   ('颶風', 12),
#   ('官員', 12),
#   ('區域', 12),
#   ('瑞典', 12),
#   ('事件', 12),
#   ('彈道', 11),
#   ('當局', 11),
#   ('總統', 11),
#   ('行動', 11),
#   ('聲明', 11),
#   ('達賴', 11),
#   ('全球', 11),
#   ('佛州', 11),
#   ('記者', 11),
#   ('柯維立', 10),
#   ('地區', 10),
#   ('丹麥', 10),
#   ('勃恩斯', 10),
#   ('賀錦麗', 9),
#   ('台海', 9),
#   ('艦艇', 9),
#   ('伊恩', 9),
#   ('夥伴', 9),
#   ('波羅的海', 9),
#   ('艾米尼', 9),
#   ('關係', 9),
#   ('行為', 8),
#   ('軍演', 8),
#   ('基礎', 8),
#   ('軍事', 8),
#   ('海岸', 8),
#   ('邊境', 8),
#   ('公司', 8),
#   ('亞洲', 8),
#   ('蒲亭', 8),
#   ('莫斯科', 8),
#   ('克里姆林宮', 8),
#   ('政策', 8),
#   ('颱風', 8),
#   ('印度', 8),
#   ('馬克宏', 8),
#   ('短程', 7),
#   ('世界', 7),
#   ('台灣', 7),
#   ('小時', 7),
#   ('防衛隊', 7),
#   ('路透社', 7),
#   ('印太', 7),
#   ('原因', 7),
#   ('穆哈瑪迪', 7),
#   ('兒童', 7),
#   ('公民', 7),
#   ('洩漏點', 7),
#   ('聯合國', 6),
#   ('基地', 6),
#   ('中俄', 6),
#   ('太平洋', 6),
#   ('行政', 6),
#   ('活動', 6),
#   ('噶廈', 6),
#   ('北京', 6),
#   ('附近', 6),
#   ('民眾', 6),
#   ('外交', 6),
#   ('新加坡', 6),
#   ('影響', 6),
#   ('組織', 6),
#   ('1號', 6),
#   ('2號', 6),
#   ('證據', 6),
#   ('氣體', 6),
#   ('俄方', 6),
#   ('設施', 6),
#   ('占領區', 6),
#   ('培斯科夫', 6),
#   ('航空', 6),
#   ('婦女', 6),
#   ('動議', 6),
#   ('海域', 5),
#   ('數據', 5),
#   ('新聞', 5),
#   ('電子報', 5),
#   ('周邊', 5),
#   ('藏人', 5),
#   ('中央', 5),
#   ('最高法院', 5),
#   ('議會', 5),
#   ('政治', 5),
#   ('法新社', 5),
#   ('經濟', 5),
#   ('能源', 5),
#   ('問題', 5),
#   ('計畫', 5),
#   ('波蘭', 5),
#   ('價格', 5),
#   ('推文', 5),
#   ('部隊', 5),
#   ('發言人', 5),
#   ('儀式', 5),
#   ('版圖', 5),
#   ('華府', 5),
#   ('俄軍', 5),
#   ('方案', 5),
#   ('禁令', 5),
#   ('哈維斯托', 5),
#   ('簽證', 5),
#   ('百里', 5),
#   ('內容', 5),
#   ('廣告', 5),
#   ('參謀', 4),
#   ('本部', 4),
#   ('高度', 4),
#   ('射程', 4),
#   ('情報', 4),
#   ('能力', 4),
#   ('脈動', 4),
#   ('電子', 4),
#   ('信箱', 4),
#   ('格式', 4),
#   ('方式', 4),
#   ('議題', 4),
#   ('自衛隊', 4),
#   ('幕僚長', 4),
#   ('立場', 4),
#   ('活佛', 4),
#   ('官方', 4),
#   ('人民', 4),
#   ('期間', 4),
#   ('演講', 4),
#   ('總理', 4),
#   ('外交部長', 4),
#   ('戰爭', 4),
#   ('能源署', 4),
#   ('位置', 4),
#   ('北約', 4),
#   ('照片', 4),
#   ('報導', 4),
#   ('領土', 4),
#   ('戰事', 4),
#   ('軍方', 4),
#   ('品牌', 4),
#   ('語言', 4),
#   ('大使', 4),
#   ('遊客', 4),
#   ('F-2', 4),
#   ('訓練', 4),
#   ('格哈茲', 4),
#   ('中將', 4),
#   ('性行為', 4),
#   ('聯盟', 4),
#   ('法國', 4),
#   ('國民', 4),
#   ('憲法', 4),
#   ('平壤', 3),
#   ('資訊', 3),
#   ('辦公室', 3),
#   ('會議', 3),
#   ('措施', 3),
#   ('副總統', 3),
#   ('尹錫悅', 3),
#   ('防衛省', 3),
#   ('海軍', 3),
#   ('東海', 3),
#   ('國防部', 3),
#   ('驅逐艦', 3),
#   ('日本海', 3),
#   ('北海道', 3),
#   ('軍艦', 3),
#   ('時間', 3),
#   ('部門', 3),
#   ('佛教', 3),
#   ('宗教', 3),
#   ('情況', 3),
#   ('外國', 3),
#   ('人員', 3)],
#  '社會': [('警方', 34),
#   ('參選人', 22),
#   ('選民', 21),
#   ('林智堅', 19),
#   ('里長', 18),
#   ('民眾', 17),
#   ('樁腳', 17),
#   ('現金', 15),
#   ('法院', 15),
#   ('嘉義市', 14),
#   ('檢方', 13),
#   ('地檢署', 12),
#   ('林秉樞', 12),
#   ('警察局', 12),
#   ('地方', 11),
#   ('高嘉瑜', 11),
#   ('酒精', 11),
#   ('警察', 10),
#   ('機關', 10),
#   ('論文', 10),
#   ('余正煌', 10),
#   ('嘉義', 9),
#   ('調查官', 9),
#   ('碩士', 9),
#   ('男子', 8),
#   ('新台幣', 8),
#   ('一審', 8),
#   ('期間', 8),
#   ('世界', 8),
#   ('電子報', 8),
#   ('天下', 8),
#   ('電子', 8),
#   ('信箱', 8),
#   ('格式', 8),
#   ('車輛', 8),
#   ('路段', 8),
#   ('李朝卿', 8),
#   ('刑法', 7),
#   ('台灣', 7),
#   ('徒刑', 7),
#   ('原因', 7),
#   ('議員', 7),
#   ('顏政德', 7),
#   ('陳政忠', 7),
#   ('台北', 7),
#   ('陳男', 7),
#   ('受刑人', 7),
#   ('林男', 6),
#   ('台北市', 6),
#   ('股票', 6),
#   ('規定', 6),
#   ('學位', 6),
#   ('臉書', 6),
#   ('土地', 5),
#   ('家屬', 5),
#   ('市議員', 5),
#   ('檢調', 5),
#   ('罪嫌', 5),
#   ('照片', 5),
#   ('法官', 5),
#   ('律師', 5),
#   ('人員', 5),
#   ('高院', 5),
#   ('機車', 5),
#   ('政府', 5),
#   ('車主', 5),
#   ('分局', 5),
#   ('國道', 5),
#   ('事故', 5),
#   ('現場', 5),
#   ('台大', 5),
#   ('獅潭鄉', 5),
#   ('刑期', 5),
#   ('楊男', 5),
#   ('明德', 5),
#   ('貨車', 5),
#   ('媒體', 4),
#   ('西區', 4),
#   ('調查站', 4),
#   ('住處', 4),
#   ('婦人', 4),
#   ('新北', 4),
#   ('法庭', 4),
#   ('警消', 4),
#   ('女子', 4),
#   ('畫面', 4),
#   ('公費', 4),
#   ('助理', 4),
#   ('最高法院', 4),
#   ('新竹', 4),
#   ('宏福', 4),
#   ('說明書', 4),
#   ('台南市', 4),
#   ('貼紙', 4),
#   ('市長', 4),
#   ('選舉', 4),
#   ('委員會', 4),
#   ('資料', 4),
#   ('苗栗縣', 4),
#   ('台中', 4),
#   ('高分院', 4),
#   ('楊植斗', 4),
#   ('通訊', 4),
#   ('證明書', 4),
#   ('日期', 4),
#   ('林信吾', 4),
#   ('名義', 4),
#   ('毀損罪', 3),
#   ('員警', 3),
#   ('過程', 3),
#   ('調查局', 3),
#   ('行政', 3),
#   ('當地', 3),
#   ('女廁', 3),
#   ('廁所', 3),
#   ('新竹市', 3),
#   ('條例', 3),
#   ('有期徒刑', 3),
#   ('建設', 3),
#   ('案件', 3),
#   ('車身', 3),
#   ('巡邏車', 3),
#   ('字樣', 3),
#   ('聯結車', 3),
#   ('車道', 3),
#   ('新聞', 3),
#   ('刑事', 3),
#   ('程序', 3),
#   ('縣長', 3),
#   ('工程', 3),
#   ('回扣案', 3),
#   ('社團', 3),
#   ('國家', 3),
#   ('周玉蔻', 3),
#   ('電視台', 3),
#   ('大門', 3),
#   ('中正', 3),
#   ('綠色', 3),
#   ('當事人', 3),
#   ('江振亨', 3),
#   ('仙山', 3),
#   ('登山客', 3),
#   ('金門縣', 3),
#   ('名字', 3),
#   ('鄉親', 3),
#   ('吉安', 2),
#   ('蔡姓', 2),
#   ('農牧', 2),
#   ('用地', 2),
#   ('墳墓', 2),
#   ('蔡男', 2),
#   ('警分局', 2),
#   ('蘇金章', 2),
#   ('林姓', 2),
#   ('柯姓', 2),
#   ('文書', 2),
#   ('祕密', 2),
#   ('靈堂', 2),
#   ('名譽', 2),
#   ('行為', 2),
#   ('私刑', 2),
#   ('刑度', 2),
#   ('精神', 2),
#   ('嘉檢', 2),
#   ('里民', 2),
#   ('龍山寺', 2),
#   ('意外', 2),
#   ('鍾姓', 2),
#   ('字條', 2),
#   ('內容', 2),
#   ('死者', 2),
#   ('監視器', 2),
#   ('姪子', 2),
#   ('事用法', 2),
#   ('違誤', 2),
#   ('被告', 2),
#   ('更四審', 2),
#   ('證交法', 2),
#   ('所得', 2),
#   ('交易', 2),
#   ('有價證券', 2),
#   ('台南', 2),
#   ('美食', 2),
#   ('文字', 2),
#   ('字體', 2),
#   ('新聞稿', 2),
#   ('網站', 2),
#   ('情況', 2),
#   ('形象', 2),
#   ('大隊', 2),
#   ('1號', 2),
#   ('北向', 2),
#   ('右後輪', 2),
#   ('中線', 2),
#   ('公路', 2),
#   ('大林', 2),
#   ('醫院', 2),
#   ('分隊', 2),
#   ('用路人', 2),
#   ('事件', 2)],
#  '文化': [('台灣', 56),
#   ('文化', 32),
#   ('電影', 20),
#   ('藝術', 18),
#   ('水道', 17),
#   ('青年', 14),
#   ('世界', 14),
#   ('台北', 14),
#   ('博物館', 13),
#   ('聖保羅', 13),
#   ('國際', 12),
#   ('廖瓊枝', 12),
#   ('司長', 12),
#   ('陳三五娘', 11),
#   ('故事', 11),
#   ('美國', 11),
#   ('巴西', 11),
#   ('雲門', 11),
#   ('設計師', 10),
#   ('疫情', 10),
#   ('中心', 10),
#   ('音樂會', 10),
#   ('劇場', 10),
#   ('設計', 9),
#   ('電子報', 9),
#   ('天下', 9),
#   ('電子', 9),
#   ('信箱', 9),
#   ('格式', 9),
#   ('人生', 9),
#   ('導演', 9),
#   ('劇團', 9),
#   ('大學', 9),
#   ('青春', 8),
#   ('歌仔戲', 8),
#   ('音樂', 8),
#   ('地點', 8),
#   ('國家', 8),
#   ('文化部', 8),
#   ('觀眾', 8),
#   ('小說', 8),
#   ('形象展', 8),
#   ('朴子', 8),
#   ('團隊', 7),
#   ('產業', 7),
#   ('民眾', 7),
#   ('影像', 7),
#   ('記者會', 7),
#   ('花園', 7),
#   ('舞台', 7),
#   ('計畫', 7),
#   ('新聞稿', 7),
#   ('拉赫瑪尼諾夫', 7),
#   ('歷史', 6),
#   ('展區', 6),
#   ('紀錄', 6),
#   ('戲曲', 6),
#   ('台南', 6),
#   ('藝博', 6),
#   ('原住民', 6),
#   ('漫畫', 6),
#   ('朋友', 6),
#   ('現場', 6),
#   ('女神', 6),
#   ('鋼琴', 6),
#   ('年曆', 6),
#   ('電影展', 6),
#   ('規劃', 6),
#   ('高雄', 5),
#   ('陳其邁', 5),
#   ('城市', 5),
#   ('主題', 5),
#   ('活動', 5),
#   ('特展', 5),
#   ('遊戲', 5),
#   ('畫廊', 5),
#   ('協會', 5),
#   ('戲劇', 5),
#   ('演員', 5),
#   ('湯姆漢克斯', 5),
#   ('政策', 5),
#   ('張正傑', 5),
#   ('輪椅族', 5),
#   ('黃騰輝', 5),
#   ('謝如欣', 5),
#   ('影展', 5),
#   ('新作', 5),
#   ('設計展', 4),
#   ('高雄市', 4),
#   ('政府', 4),
#   ('市長', 4),
#   ('期間', 4),
#   ('科技', 4),
#   ('概念', 4),
#   ('內容', 4),
#   ('展商', 4),
#   ('空間', 4),
#   ('冠狀', 4),
#   ('病毒', 4),
#   ('疾病', 4),
#   ('李存勗', 4),
#   ('台灣陣', 4),
#   ('文創', 4),
#   ('吳曜宇', 4),
#   ('小調', 4),
#   ('協奏曲', 4),
#   ('經典', 4),
#   ('秘密', 4),
#   ('林宏義', 4),
#   ('李永得', 4),
#   ('戲劇團', 4),
#   ('節目', 4),
#   ('作品', 4),
#   ('代表', 3),
#   ('才華', 3),
#   ('高雄港', 3),
#   ('建設', 3),
#   ('中島', 3),
#   ('李小平', 3),
#   ('陳三五', 3),
#   ('情節', 3),
#   ('方式', 3),
#   ('角色', 3),
#   ('記憶', 3),
#   ('台南市', 3),
#   ('文化局', 3),
#   ('古蹟', 3),
#   ('系列', 3),
#   ('園區', 3),
#   ('葉澤山', 3),
#   ('環境', 3),
#   ('模式', 3),
#   ('張逸羣', 3),
#   ('專區', 3),
#   ('優伶', 3),
#   ('天子', 3),
#   ('主角', 3),
#   ('編劇', 3),
#   ('人物', 3),
#   ('劇情', 3),
#   ('影帝', 3),
#   ('時間', 3),
#   ('文總', 3),
#   ('傳統', 3),
#   ('外貿', 3),
#   ('榕樹', 3),
#   ('廣場', 3),
#   ('世界級', 3),
#   ('鋼琴家', 3),
#   ('網站', 3),
#   ('學院', 3),
#   ('嘉藝', 3),
#   ('聚落', 3),
#   ('頭君', 3),
#   ('機台', 3),
#   ('許有仁', 3),
#   ('策展', 3),
#   ('時代', 3),
#   ('交響樂團', 3),
#   ('馬斯里夫', 3),
#   ('大賽', 3),
#   ('玫瑰', 3),
#   ('畫作', 3),
#   ('旅途', 3),
#   ('草根性', 3),
#   ('視野', 3),
#   ('莫子儀', 3),
#   ('影人', 3),
#   ('委員', 3),
#   ('麥洛', 3),
#   ('開幕片', 3),
#   ('趙德胤', 3),
#   ('幕後', 3),
#   ('資源', 3),
#   ('副司長', 3),
#   ('明華園', 3),
#   ('總團', 3),
#   ('木偶', 3),
#   ('青設', 2),
#   ('夜泊', 2),
#   ('商會', 2),
#   ('世代', 2),
#   ('創意', 2),
#   ('青年局', 2),
#   ('棧五庫', 2),
#   ('貨物', 2),
#   ('吞吐量', 2),
#   ('蓬萊', 2),
#   ('商港區', 2),
#   ('經濟', 2),
#   ('張以理', 2),
#   ('時尚', 2),
#   ('柯志恩', 2),
#   ('成果', 2),
#   ('媒體', 2),
#   ('對話', 2),
#   ('身段', 2),
#   ('張孟逸', 2),
#   ('社群', 2),
#   ('劇本', 2)],
#  '兩岸': [('中國', 73),
#   ('國家', 27),
#   ('疫情', 26),
#   ('政策', 26),
#   ('人民', 25),
#   ('兩岸', 22),
#   ('關係', 20),
#   ('住房', 18),
#   ('政府', 18),
#   ('美元', 18),
#   ('人員', 17),
#   ('中共', 17),
#   ('匯率', 17),
#   ('許智峯', 17),
#   ('核酸', 16),
#   ('香港', 16),
#   ('人民幣', 15),
#   ('安倍', 15),
#   ('謠言', 15),
#   ('大陸', 14),
#   ('銀行', 14),
#   ('市場', 14),
#   ('利率', 13),
#   ('邱垂正', 13),
#   ('日本', 13),
#   ('官方', 12),
#   ('陸委會', 12),
#   ('世界', 12),
#   ('外交', 12),
#   ('措施', 11),
#   ('法庭', 11),
#   ('健康碼', 11),
#   ('中華民國', 10),
#   ('貨幣', 10),
#   ('經濟', 10),
#   ('工作', 9),
#   ('會議', 9),
#   ('社會', 9),
#   ('萬鋼', 9),
#   ('利益', 9),
#   ('機制', 8),
#   ('中央', 8),
#   ('民眾', 8),
#   ('階段性', 8),
#   ('當地', 8),
#   ('小三通', 8),
#   ('共識', 8),
#   ('國葬', 8),
#   ('指數', 8),
#   ('胡錫進', 8),
#   ('期間', 7),
#   ('委員會', 7),
#   ('症狀', 7),
#   ('地區', 7),
#   ('政治', 7),
#   ('專項', 7),
#   ('馬朝旭', 7),
#   ('風險', 6),
#   ('微博', 6),
#   ('貸款', 6),
#   ('下限', 6),
#   ('需求', 6),
#   ('商品', 6),
#   ('城市', 6),
#   ('上述', 6),
#   ('領域', 6),
#   ('台灣', 6),
#   ('憲法', 6),
#   ('通膨', 6),
#   ('民生', 6),
#   ('天津', 6),
#   ('國務院', 5),
#   ('網友', 5),
#   ('媒體', 5),
#   ('信貸', 5),
#   ('央行', 5),
#   ('房地產', 5),
#   ('價格', 5),
#   ('房貸', 5),
#   ('專家', 5),
#   ('發言人', 5),
#   ('電子報', 5),
#   ('天下', 5),
#   ('電子', 5),
#   ('信箱', 5),
#   ('格式', 5),
#   ('記者會', 5),
#   ('因素', 5),
#   ('當局', 5),
#   ('北京', 5),
#   ('壓力', 5),
#   ('邦交', 5),
#   ('習近平', 5),
#   ('時代', 5),
#   ('代表', 5),
#   ('晉三', 5),
#   ('病例', 5),
#   ('陸家嘴', 5),
#   ('本土', 5),
#   ('訊息', 5),
#   ('報告', 5),
#   ('靜態', 5),
#   ('網路', 5),
#   ('行動', 5),
#   ('平台', 5),
#   ('標籤', 5),
#   ('陽性', 5),
#   ('官員', 4),
#   ('居家', 4),
#   ('外鎖門', 4),
#   ('方式', 4),
#   ('地方', 4),
#   ('小時', 4),
#   ('COVID-19', 4),
#   ('要求', 4),
#   ('基礎', 4),
#   ('新聞', 4),
#   ('部門', 4),
#   ('剛性', 4),
#   ('原則', 4),
#   ('範圍', 4),
#   ('環境', 4),
#   ('整體', 4),
#   ('陸方', 4),
#   ('情況', 4),
#   ('單位', 4),
#   ('權益', 4),
#   ('總統', 4),
#   ('中華', 4),
#   ('共和國', 4),
#   ('消費者', 4),
#   ('中方', 4),
#   ('首相', 4),
#   ('外交部', 4),
#   ('汪文斌', 4),
#   ('領導人', 4),
#   ('東京', 4),
#   ('儀式', 4),
#   ('衛生', 4),
#   ('區域', 4),
#   ('員工', 4),
#   ('陰性', 4),
#   ('立法會', 4),
#   ('議員', 4),
#   ('海外', 4),
#   ('法院', 4),
#   ('司法', 4),
#   ('林卓廷', 4),
#   ('衝突', 4),
#   ('事件', 4),
#   ('物價', 4),
#   ('文章', 4),
#   ('老胡', 4),
#   ('作用', 4),
#   ('標記', 4),
#   ('樣本', 4),
#   ('黑龍江', 4),
#   ('負評', 3),
#   ('居民', 3),
#   ('上海', 3),
#   ('患者', 3),
#   ('生命', 3),
#   ('評論', 3),
#   ('城市政府', 3),
#   ('官網', 3),
#   ('工具箱', 3),
#   ('商業性', 3),
#   ('規定', 3),
#   ('水準', 3),
#   ('報導', 3),
#   ('重點', 3),
#   ('貓熊', 3),
#   ('台北', 3),
#   ('動物園', 3),
#   ('需要', 3),
#   ('機關', 3),
#   ('金馬', 3),
#   ('落差', 3),
#   ('時機', 3),
#   ('對岸', 3),
#   ('條例', 3),
#   ('法令', 3),
#   ('事務', 3),
#   ('馬英九', 3),
#   ('國內', 3),
#   ('各界', 3),
#   ('主權', 3),
#   ('力度', 3),
#   ('融資', 3),
#   ('主席', 3),
#   ('招待會', 3),
#   ('貢獻', 3),
#   ('政協', 3),
#   ('副主席', 3),
#   ('鐵路', 3),
#   ('冠狀', 3),
#   ('病毒', 3),
#   ('疾病', 3),
#   ('短期', 3),
#   ('公眾號', 3)],
#  '全部': [('台灣', 273),
#   ('中國', 127),
#   ('國家', 106),
#   ('世界', 97),
#   ('民眾', 89),
#   ('國際', 87),
#   ('電子', 87),
#   ('美國', 86),
#   ('政府', 79),
#   ('政策', 69),
#   ('市場', 68),
#   ('疫情', 66),
#   ('信箱', 64),
#   ('新台幣', 64),
#   ('金管會', 63),
#   ('日本', 61),
#   ('電子報', 60),
#   ('格式', 60),
#   ('俄羅斯', 59),
#   ('天下', 56),
#   ('公司', 53),
#   ('英國', 50),
#   ('台北', 49),
#   ('指數', 48),
#   ('人員', 45),
#   ('關係', 43),
#   ('全球', 43),
#   ('措施', 41),
#   ('方式', 41),
#   ('時間', 41),
#   ('烏克蘭', 40),
#   ('台股', 40),
#   ('少年', 39),
#   ('經濟', 38),
#   ('會議', 38),
#   ('銀行', 38),
#   ('金融', 38),
#   ('警方', 38),
#   ('中心', 36),
#   ('社會', 36),
#   ('電影', 36),
#   ('人民', 35),
#   ('文化', 35),
#   ('聯盟', 35),
#   ('新聞稿', 35),
#   ('期間', 35),
#   ('產業', 34),
#   ('業者', 34),
#   ('基金', 34),
#   ('法院', 33),
#   ('歐洲', 33),
#   ('參選人', 32),
#   ('網路', 30),
#   ('總統', 30),
#   ('記者會', 30),
#   ('北溪', 30),
#   ('管線', 30),
#   ('記者', 29),
#   ('中央', 29),
#   ('內容', 29),
#   ('疫苗', 29),
#   ('平台', 29),
#   ('德國', 29),
#   ('代表', 28),
#   ('媒體', 28),
#   ('考試', 28),
#   ('飛彈', 28),
#   ('戰機', 28),
#   ('美元', 28),
#   ('區域', 27),
#   ('地區', 27),
#   ('官員', 27),
#   ('事件', 27),
#   ('兩岸', 26),
#   ('問題', 26),
#   ('行動', 26),
#   ('匯率', 26),
#   ('芬蘭', 26),
#   ('資訊', 25),
#   ('警察', 25),
#   ('台積電', 25),
#   ('台南', 24),
#   ('北韓', 24),
#   ('產品', 23),
#   ('蓬佩奧', 23),
#   ('風險', 23),
#   ('工作', 23),
#   ('委員會', 23),
#   ('情況', 23),
#   ('地方', 23),
#   ('央行', 23),
#   ('技術', 22),
#   ('節目', 22),
#   ('立法院', 22),
#   ('網站', 22),
#   ('規定', 22),
#   ('活動', 22),
#   ('空軍', 22),
#   ('價格', 22),
#   ('科技', 22),
#   ('外資', 22),
#   ('角色', 22),
#   ('官方', 22),
#   ('需求', 21),
#   ('憲法', 21),
#   ('臉書', 21),
#   ('機制', 21),
#   ('計畫', 21),
#   ('員工', 21),
#   ('香港', 21),
#   ('天然氣', 21),
#   ('選民', 21),
#   ('系統', 20),
#   ('企業', 20),
#   ('程序', 20),
#   ('機關', 20),
#   ('目標', 20),
#   ('原因', 20),
#   ('教官', 20),
#   ('當地', 20),
#   ('公民', 20),
#   ('病毒', 20),
#   ('疾病', 20),
#   ('股價', 20),
#   ('現金', 20),
#   ('俄國', 20),
#   ('中共', 19),
#   ('現場', 19),
#   ('關鍵', 19),
#   ('司法', 19),
#   ('資料', 19),
#   ('小時', 19),
#   ('壓力', 19),
#   ('環境', 19),
#   ('外交', 19),
#   ('投信', 19),
#   ('曝險', 19),
#   ('林智堅', 19),
#   ('南韓', 18),
#   ('高雄', 18),
#   ('邊境', 18),
#   ('條例', 18),
#   ('事項', 18),
#   ('推特', 18),
#   ('國內', 18),
#   ('大學', 18),
#   ('安倍', 18),
#   ('統計', 18),
#   ('當局', 18),
#   ('單位', 18),
#   ('終場', 18),
#   ('越南', 18),
#   ('里長', 18),
#   ('藝術', 18),
#   ('住房', 18),
#   ('COVID-19', 17),
#   ('行為', 17),
#   ('韓國', 17),
#   ('基礎', 17),
#   ('晶片', 17),
#   ('條文', 17),
#   ('媽媽', 17),
#   ('試題', 17),
#   ('中華民國', 17),
#   ('機會', 17),
#   ('觀眾', 17),
#   ('航空', 17),
#   ('海外', 17),
#   ('核酸', 17),
#   ('股市', 17),
#   ('客戶', 17),
#   ('嘉義', 17),
#   ('樁腳', 17),
#   ('水道', 17),
#   ('許智峯', 17),
#   ('外交部', 16),
#   ('法律', 16),
#   ('半導體', 16),
#   ('中央社', 16),
#   ('共識', 16),
#   ('團隊', 16),
#   ('運動', 16),
#   ('設施', 16),
#   ('紀錄', 16),
#   ('戰爭', 16),
#   ('遊戲', 16),
#   ('中華', 16),
#   ('冠狀', 16),
#   ('球員', 16),
#   ('年增', 16),
#   ('淨值', 16),
#   ('利率', 16),
#   ('新加坡', 16),
#   ('人民幣', 16),
#   ('設計', 16),
#   ('嘉義市', 16),
#   ('規模', 15),
#   ('資源', 15),
#   ('台海', 15),
#   ('陸委會', 15)]}

# %%
data['政治'][0:5]
# Out:
# [('台灣', 71), ('少年', 36), ('考試', 28), ('國際', 25), ('國家', 23)]

# %% [markdown]
# # Define the function to use in Django website

# %%
# Load data
df_data = pd.read_csv('cna_news_top200keywords_category_ws_pos.csv',sep=',')

# Prepare top keys data with dictionary format
data = {}
for idx, row in df_data.iterrows():
    data[row['category']] = eval(row['top_keys'])

# %%
data
# Out:
# {'政治': [('台灣', 71),
#   ('少年', 36),
#   ('考試', 28),
#   ('國際', 25),
#   ('國家', 23),
#   ('蓬佩奧', 22),
#   ('中國', 19),
#   ('試題', 17),
#   ('世界', 16),
#   ('立法院', 15),
#   ('條文', 15),
#   ('疑義', 15),
#   ('政策', 14),
#   ('社會', 14),
#   ('社宅', 14),
#   ('中選會', 14),
#   ('代表', 13),
#   ('陳時中', 13),
#   ('外交部', 12),
#   ('美國', 12),
#   ('政府', 12),
#   ('民眾', 12),
#   ('蘇貞昌', 12),
#   ('產業', 12),
#   ('全球', 12),
#   ('警械', 12),
#   ('警察', 12),
#   ('司法', 12),
#   ('法院', 12),
#   ('公民', 12),
#   ('林佳龍', 11),
#   ('程序', 11),
#   ('韓國', 11),
#   ('人員', 11),
#   ('憲法', 11),
#   ('運動', 11),
#   ('中心', 10),
#   ('參選人', 10),
#   ('副總統', 10),
#   ('方式', 10),
#   ('柯志恩', 10),
#   ('系統', 9),
#   ('黃偉哲', 9),
#   ('總統', 9),
#   ('法律', 9),
#   ('高雄', 9),
#   ('小組', 9),
#   ('新聞稿', 9),
#   ('應考人', 9),
#   ('電視', 9),
#   ('楊文科', 9),
#   ('貿易', 8),
#   ('台北', 8),
#   ('問題', 8),
#   ('民主', 8),
#   ('條例', 8),
#   ('簽證', 8),
#   ('措施', 8),
#   ('考選部', 8),
#   ('空軍', 8),
#   ('目標', 8),
#   ('事件', 8),
#   ('台商', 8),
#   ('田中光', 7),
#   ('天下', 7),
#   ('電子', 7),
#   ('區域', 7),
#   ('聯合國', 7),
#   ('大會', 7),
#   ('國民黨', 7),
#   ('力量', 7),
#   ('鄭炳元', 7),
#   ('台南', 7),
#   ('朝野', 7),
#   ('院會', 7),
#   ('草案', 7),
#   ('事項', 7),
#   ('時間', 7),
#   ('董事會', 7),
#   ('直升機', 7),
#   ('廠商', 6),
#   ('電子報', 6),
#   ('信箱', 6),
#   ('格式', 6),
#   ('關係', 6),
#   ('媒體', 6),
#   ('印太', 6),
#   ('澳洲', 6),
#   ('網路', 6),
#   ('台海', 6),
#   ('政見', 6),
#   ('原則', 6),
#   ('行政院', 6),
#   ('會議', 6),
#   ('時機', 6),
#   ('考試院', 6),
#   ('任務', 6),
#   ('董事長', 6),
#   ('鄭優', 6),
#   ('津貼', 6),
#   ('高雄市', 6),
#   ('農會', 6),
#   ('司法院', 6),
#   ('戰機', 6),
#   ('訓練', 6),
#   ('竹北', 6),
#   ('修正案', 6),
#   ('吳釗燮', 6),
#   ('規模', 5),
#   ('戴維森', 5),
#   ('武器', 5),
#   ('資訊', 5),
#   ('網民', 5),
#   ('需求', 5),
#   ('立委', 5),
#   ('賴清德', 5),
#   ('現場', 5),
#   ('身體', 5),
#   ('市長', 5),
#   ('理由', 5),
#   ('挑戰', 5),
#   ('關鍵', 5),
#   ('黨團', 5),
#   ('警員', 5),
#   ('內政部', 5),
#   ('機關', 5),
#   ('意見', 5),
#   ('期限', 5),
#   ('內容', 5),
#   ('規定', 5),
#   ('住宅', 5),
#   ('台北市', 5),
#   ('彭揚凱', 5),
#   ('飛官', 5),
#   ('黑鷹', 5),
#   ('中華民國', 5),
#   ('高考', 5),
#   ('智慧', 4),
#   ('經濟', 4),
#   ('疫情', 4),
#   ('實體', 4),
#   ('經貿', 4),
#   ('酒會', 4),
#   ('日本', 4),
#   ('空間', 4),
#   ('組織', 4),
#   ('民進黨', 4),
#   ('新北', 4),
#   ('人民', 4),
#   ('選舉', 4),
#   ('人士', 4),
#   ('經驗', 4),
#   ('聯盟', 4),
#   ('共識', 4),
#   ('致命性', 4),
#   ('情境', 4),
#   ('生命', 4),
#   ('槍械', 4),
#   ('民進黨團', 4),
#   ('中央', 4),
#   ('東南亞', 4),
#   ('作業', 4),
#   ('線上', 4),
#   ('公民權', 4),
#   ('社會局', 4),
#   ('市府', 4),
#   ('市民', 4),
#   ('協會', 4),
#   ('陳其邁', 4),
#   ('刑事', 4),
#   ('雷虎', 4),
#   ('一級', 4),
#   ('文官', 4),
#   ('城區', 4),
#   ('國民', 4),
#   ('蔬菜', 4),
#   ('期間', 4),
#   ('童振源', 4),
#   ('漁業展', 3),
#   ('農業', 3),
#   ('國內外', 3),
#   ('聖文森', 3),
#   ('印尼', 3),
#   ('主任', 3),
#   ('辦事處', 3),
#   ('大使館', 3),
#   ('國務卿', 3),
#   ('主持人', 3),
#   ('台灣人', 3),
#   ('自由', 3),
#   ('資源', 3),
#   ('美方', 3),
#   ('工具', 3),
#   ('夥伴', 3),
#   ('情勢', 3),
#   ('共產黨', 3),
#   ('行為', 3),
#   ('現狀', 3),
#   ('市政', 3),
#   ('蔡英文', 3)],
#  '科技': [('太空', 12),
#   ('網路', 10),
#   ('網站', 10),
#   ('小行星', 10),
#   ('國際', 9),
#   ('科技', 8),
#   ('太空站', 7),
#   ('民眾', 7),
#   ('趨勢', 7),
#   ('平台', 7),
#   ('行星', 7),
#   ('地球', 6),
#   ('指揮官', 6),
#   ('影音', 6),
#   ('帳號', 6),
#   ('克利斯托佛瑞提', 5),
#   ('女性', 5),
#   ('時間', 5),
#   ('內容', 5),
#   ('臉書', 5),
#   ('觀眾', 5),
#   ('數量', 5),
#   ('遊戲', 5),
#   ('衛星', 5),
#   ('歐洲', 4),
#   ('阿騰葉夫', 4),
#   ('總署', 4),
#   ('格式', 4),
#   ('電子', 4),
#   ('陷阱', 4),
#   ('玩家', 4),
#   ('影像', 4),
#   ('義大利', 3),
#   ('太空人', 3),
#   ('機會', 3),
#   ('任務', 3),
#   ('台灣', 3),
#   ('世界', 3),
#   ('電子報', 3),
#   ('天下', 3),
#   ('信箱', 3),
#   ('方式', 3),
#   ('訊息', 3),
#   ('集團', 3),
#   ('交易', 3),
#   ('迪莫弗斯', 3),
#   ('撞擊點', 3),
#   ('儀式', 2),
#   ('烏克蘭', 2),
#   ('軌道', 2),
#   ('紀錄', 2),
#   ('保持人', 2),
#   ('時期', 2),
#   ('美國', 2),
#   ('道路', 2),
#   ('公司', 2),
#   ('功能', 2),
#   ('資格', 2),
#   ('收益', 2),
#   ('新聞稿', 2),
#   ('資料', 2),
#   ('全球', 2),
#   ('資安', 2),
#   ('類型', 2),
#   ('洪偉淦', 2),
#   ('手法', 2),
#   ('金錢', 2),
#   ('個資', 2),
#   ('統計', 2),
#   ('市場', 2),
#   ('簡訊', 2),
#   ('錢財', 2),
#   ('寶物', 2),
#   ('國家', 2),
#   ('NASA', 2),
#   ('飛行器', 2),
#   ('碎片', 2),
#   ('畫面', 2),
#   ('科學家', 2),
#   ('周圍', 2),
#   ('科學', 2),
#   ('團隊', 2),
#   ('現場', 1),
#   ('首位', 1),
#   ('指揮權', 1),
#   ('法新社', 1),
#   ('指揮棒', 1),
#   ('俄籍', 1),
#   ('戰事', 1),
#   ('金色', 1),
#   ('鑰匙', 1),
#   ('克利斯托佛瑞提曾', 1),
#   ('空軍', 1),
#   ('飛行員', 1),
#   ('美國籍', 1),
#   ('網頁', 1),
#   ('美國人', 1),
#   ('俄羅斯人', 1),
#   ('阿波羅', 1),
#   ('聯合號', 1),
#   ('計畫', 1),
#   ('冷戰', 1),
#   ('蘇聯', 1),
#   ('關係', 1),
#   ('戰爭', 1),
#   ('人員', 1),
#   ('情況', 1),
#   ('地面', 1),
#   ('中心', 1),
#   ('指示', 1),
#   ('決定', 1),
#   ('抖音', 1),
#   ('影片', 1),
#   ('旗下', 1),
#   ('好評', 1),
#   ('用戶點', 1),
#   ('擊臉書', 1),
#   ('欄位', 1),
#   ('短秒數', 1),
#   ('版位', 1),
#   ('動態牆', 1),
#   ('社團', 1),
#   ('工具', 1),
#   ('星星', 1),
#   ('留言', 1),
#   ('業者', 1),
#   ('指標性', 1),
#   ('台灣區', 1),
#   ('香港區', 1),
#   ('總經理', 1),
#   ('習慣', 1),
#   ('話題', 1),
#   ('速度', 1),
#   ('想像', 1),
#   ('損失', 1),
#   ('影響', 1),
#   ('層面', 1),
#   ('全家', 1),
#   ('大小', 1),
#   ('成員', 1),
#   ('生活', 1),
#   ('整體', 1),
#   ('氛圍', 1),
#   ('總數', 1),
#   ('經濟', 1),
#   ('商機', 1),
#   ('吸引力', 1),
#   ('產品', 1),
#   ('圖片', 1),
#   ('價格', 1),
#   ('消費', 1),
#   ('人頭', 1),
#   ('網拍', 1),
#   ('冤大頭', 1),
#   ('特徵', 1),
#   ('售價', 1),
#   ('行情', 1),
#   ('網址', 1),
#   ('意義', 1),
#   ('地址', 1),
#   ('電話', 1),
#   ('銀行', 1),
#   ('管道', 1),
#   ('群組', 1),
#   ('股票', 1),
#   ('理由', 1),
#   ('代幣', 1),
#   ('駭客', 1),
#   ('貨幣', 1),
#   ('角色', 1),
#   ('裝備', 1),
#   ('點數', 1),
#   ('儲值金', 1),
#   ('限制', 1),
#   ('話術', 1),
#   ('身分', 1),
#   ('官方', 1),
#   ('郵件', 1),
#   ('問題', 1),
#   ('消費者', 1),
#   ('信用卡', 1),
#   ('供應鏈', 1),
#   ('中樞', 1),
#   ('航空', 1),
#   ('近距離', 1),
#   ('大型', 1),
#   ('岩石', 1),
#   ('太空船', 1),
#   ('機制', 1),
#   ('目標', 1),
#   ('期間', 1),
#   ('輕型', 1),
#   ('立方體', 1),
#   ('角度', 1),
#   ('經過', 1),
#   ('距離', 1),
#   ('雙相機', 1),
#   ('系統', 1),
#   ('證據', 1),
#   ('時速', 1)],
#  '運動': [('聯盟', 21),
#   ('球員', 16),
#   ('賽季', 15),
#   ('全壘打', 14),
#   ('賈吉', 14),
#   ('比賽', 13),
#   ('美聯', 13),
#   ('台灣', 12),
#   ('王柏融', 12),
#   ('安打', 11),
#   ('球隊', 11),
#   ('黃暐傑', 11),
#   ('職棒', 9),
#   ('卡達', 9),
#   ('洋基', 9),
#   ('球迷', 8),
#   ('中信', 8),
#   ('兄弟隊', 8),
#   ('谷毛唯嘉', 8),
#   ('歐洲', 8),
#   ('陳偉殷', 8),
#   ('林岳平', 7),
#   ('賽事', 7),
#   ('獵鷹', 7),
#   ('藍鳥', 7),
#   ('紀錄', 7),
#   ('病毒', 6),
#   ('一軍', 6),
#   ('兄弟', 6),
#   ('世足賽', 6),
#   ('足球', 6),
#   ('世界', 6),
#   ('職業', 6),
#   ('火腿', 6),
#   ('吉力吉撈', 5),
#   ('獅隊', 5),
#   ('龍隊', 5),
#   ('投手', 5),
#   ('洋投', 5),
#   ('桃猿隊', 5),
#   ('王偉祥', 5),
#   ('新台幣', 5),
#   ('季後賽', 5),
#   ('曾文鼎', 5),
#   ('記者會', 5),
#   ('特攻', 5),
#   ('台鋼', 5),
#   ('時間', 5),
#   ('例行賽', 5),
#   ('3A', 5),
#   ('影片', 4),
#   ('中華', 4),
#   ('鞏冠', 4),
#   ('COVID-19', 4),
#   ('冠狀', 4),
#   ('疾病', 4),
#   ('打點', 4),
#   ('世足', 4),
#   ('郭嚴文', 4),
#   ('生涯', 4),
#   ('目標', 4),
#   ('新人王', 4),
#   ('宇宙', 4),
#   ('棒球', 4),
#   ('打擊率', 4),
#   ('成本', 4),
#   ('美國', 4),
#   ('經典賽', 4),
#   ('馬瑞斯', 4),
#   ('味全龍', 3),
#   ('主場', 3),
#   ('胡智為', 3),
#   ('中繼', 3),
#   ('二壘', 3),
#   ('比分', 3),
#   ('王維中', 3),
#   ('對手', 3),
#   ('陰性', 3),
#   ('法新社', 3),
#   ('疫情', 3),
#   ('國際', 3),
#   ('總會', 3),
#   ('衛生部', 3),
#   ('球團', 3),
#   ('德保拉', 3),
#   ('豪勁', 3),
#   ('觸身球', 3),
#   ('進度', 3),
#   ('高爾夫', 3),
#   ('邀請賽', 3),
#   ('柏忌', 3),
#   ('標準', 3),
#   ('優勢', 3),
#   ('球場', 3),
#   ('機會', 3),
#   ('總經理', 3),
#   ('劉志威', 3),
#   ('運彩', 3),
#   ('中鋒', 3),
#   ('名單', 3),
#   ('籃球', 3),
#   ('合約', 3),
#   ('總教練', 3),
#   ('劉孟竹', 3),
#   ('張樹人', 3),
#   ('日本', 3),
#   ('打擊', 3),
#   ('聯賽', 3),
#   ('傷兵', 3),
#   ('足壇', 3),
#   ('英超', 3),
#   ('近況', 3),
#   ('肩膀', 3),
#   ('教練', 3),
#   ('重砲', 3),
#   ('運動家隊', 3),
#   ('來源', 2),
#   ('單場', 2),
#   ('統一獅', 2),
#   ('台南', 2),
#   ('棒球場', 2),
#   ('年度', 2),
#   ('勝率', 2),
#   ('李凱威', 2),
#   ('攻勢', 2),
#   ('陽春砲', 2),
#   ('新高', 2),
#   ('敗投', 2),
#   ('MVP', 2),
#   ('當局', 2),
#   ('世界盃', 2),
#   ('小時', 2),
#   ('結果', 2),
#   ('會內賽', 2),
#   ('體育', 2),
#   ('準則', 2),
#   ('隊史', 2),
#   ('危機', 2),
#   ('陳文杰', 2),
#   ('蔡齊哲', 2),
#   ('僵局', 2),
#   ('隊友', 2),
#   ('出局數', 2),
#   ('好手', 2),
#   ('名人賽', 2),
#   ('三商杯', 2),
#   ('回合', 2),
#   ('鐵桿', 2),
#   ('準度', 2),
#   ('洪健堯', 2),
#   ('選手', 2),
#   ('本土', 2),
#   ('控衛', 2),
#   ('新秀', 2),
#   ('蔣淯安', 2),
#   ('時期', 2),
#   ('電子報', 2),
#   ('天下', 2),
#   ('電子', 2),
#   ('信箱', 2),
#   ('格式', 2),
#   ('動力', 2),
#   ('體育台', 2),
#   ('方式', 2),
#   ('蔡尚樺', 2),
#   ('方向', 2),
#   ('秘書長', 2),
#   ('千葉羅德', 2),
#   ('海洋隊', 2),
#   ('打數', 2),
#   ('二軍', 2),
#   ('日職', 2),
#   ('客場', 2),
#   ('賽程', 2),
#   ('豪頓', 2),
#   ('研究', 2),
#   ('歐國聯', 2),
#   ('臉書', 2),
#   ('左投', 2),
#   ('阪神虎隊', 2),
#   ('台灣隊', 2),
#   ('教練團', 2),
#   ('會議', 2),
#   ('大聯盟', 2),
#   ('紐約', 2),
#   ('多倫多', 2),
#   ('觀眾', 2),
#   ('左外野', 2),
#   ('牛棚', 2),
#   ('打席', 2),
#   ('巨人隊', 2),
#   ('打者', 2),
#   ('勝差', 1),
#   ('。獅隊', 1),
#   ('亂流', 1),
#   ('先鋒', 1),
#   ('跑者', 1),
#   ('味全龍隊', 1),
#   ('大局', 1),
#   ('。龍隊', 1)],
#  '證卷': [('台股', 36),
#   ('指數', 32),
#   ('台積電', 25),
#   ('新台幣', 23),
#   ('外資', 21),
#   ('投信', 17),
#   ('股價', 16),
#   ('股市', 15),
#   ('終場', 15),
#   ('淨值', 15),
#   ('電子', 13),
#   ('法人', 13),
#   ('漲幅', 12),
#   ('潤泰', 12),
#   ('美國', 11),
#   ('美股', 11),
#   ('個股', 10),
#   ('公司', 10),
#   ('尾盤', 10),
#   ('金融', 10),
#   ('營收', 9),
#   ('台泥', 9),
#   ('容逸燊', 9),
#   ('央行', 9),
#   ('客戶', 9),
#   ('鴻海', 8),
#   ('市值', 8),
#   ('期貨', 8),
#   ('台灣', 7),
#   ('交易日', 7),
#   ('世界', 7),
#   ('強彈', 7),
#   ('英國', 7),
#   ('金管會', 7),
#   ('早盤', 7),
#   ('跌幅', 7),
#   ('市場', 6),
#   ('壓力', 6),
#   ('投資人', 6),
#   ('走勢', 6),
#   ('電子股', 6),
#   ('金融股', 6),
#   ('自營商', 6),
#   ('證券', 6),
#   ('危機', 6),
#   ('短線', 6),
#   ('匯率', 6),
#   ('交易', 6),
#   ('財報', 6),
#   ('力積電', 6),
#   ('人壽', 6),
#   ('張振山', 6),
#   ('時間', 5),
#   ('半導體', 5),
#   ('成交值', 5),
#   ('航運', 5),
#   ('陸資', 5),
#   ('動向', 5),
#   ('交易所', 5),
#   ('單位', 5),
#   ('需求', 5),
#   ('銀行', 5),
#   ('債市', 5),
#   ('新低', 5),
#   ('如興', 5),
#   ('股東', 5),
#   ('價差', 5),
#   ('現貨', 5),
#   ('南山', 5),
#   ('現金', 5),
#   ('道瓊', 4),
#   ('那斯達克', 4),
#   ('幅度', 4),
#   ('年增', 4),
#   ('規模', 4),
#   ('新高', 4),
#   ('政策', 4),
#   ('興櫃', 4),
#   ('關係', 4),
#   ('業務', 4),
#   ('經濟', 4),
#   ('英格蘭', 4),
#   ('聯準會', 4),
#   ('賣壓', 4),
#   ('中小型股', 4),
#   ('董事', 4),
#   ('情況', 4),
#   ('大盤', 4),
#   ('潤泰全', 4),
#   ('會議', 4),
#   ('殖利率', 3),
#   ('奇摩', 3),
#   ('爆紅台', 3),
#   ('股榜', 3),
#   ('企業', 3),
#   ('產業', 3),
#   ('訂單', 3),
#   ('華新', 3),
#   ('副總經理', 3),
#   ('美元', 3),
#   ('程曦', 3),
#   ('國內', 3),
#   ('電子報', 3),
#   ('天下', 3),
#   ('信箱', 3),
#   ('格式', 3),
#   ('晶圓', 3),
#   ('行情', 3),
#   ('會計師', 3),
#   ('事務所', 3),
#   ('國際', 3),
#   ('台北', 3),
#   ('電子期', 3),
#   ('收盤價', 3),
#   ('價格', 3),
#   ('張數', 3),
#   ('櫃買', 3),
#   ('投控', 3),
#   ('基本面', 3),
#   ('新股', 3),
#   ('海外', 3),
#   ('公債', 2),
#   ('族群', 2),
#   ('產品', 2),
#   ('胡連', 2),
#   ('類股', 2),
#   ('歷史', 2),
#   ('加計盤', 2),
#   ('統計', 2),
#   ('中信金', 2),
#   ('中央社', 2),
#   ('記者', 2),
#   ('情緒', 2),
#   ('日本', 2),
#   ('全球', 2),
#   ('買盤', 2),
#   ('經驗', 2),
#   ('金控', 2),
#   ('投信連', 2),
#   ('戰略', 2),
#   ('新板', 2),
#   ('漲跌', 2),
#   ('顧客', 2),
#   ('整體', 2),
#   ('民眾', 2),
#   ('合約', 2),
#   ('後市', 2),
#   ('重點', 2),
#   ('龍頭', 2),
#   ('低點', 2),
#   ('機率', 2),
#   ('言論', 2),
#   ('臨時會', 2),
#   ('董事長', 2),
#   ('張水江', 2),
#   ('財務', 2),
#   ('陳怡如', 2),
#   ('媒體', 2),
#   ('基金', 2),
#   ('法律', 2),
#   ('持股', 2),
#   ('金融期', 2),
#   ('期交所', 2),
#   ('金額', 2),
#   ('權值股', 2),
#   ('聯發科', 2),
#   ('聯電', 2),
#   ('日月光', 2),
#   ('航運股', 2),
#   ('長榮', 2),
#   ('平盤', 2),
#   ('吳繼先', 2),
#   ('預期', 2),
#   ('強勢', 2),
#   ('階段', 2),
#   ('面板', 2),
#   ('變化', 2),
#   ('潤泰新', 2),
#   ('比例', 2),
#   ('信用', 2),
#   ('年增率', 2),
#   ('收益', 2),
#   ('F4', 2),
#   ('股期市', 2),
#   ('憑證', 2),
#   ('股權', 2),
#   ('工業', 1),
#   ('標準', 1),
#   ('普爾', 1),
#   ('次數', 1),
#   ('瀏覽量', 1),
#   ('季增', 1),
#   ('爆紅台股榜', 1),
#   ('，元', 1),
#   ('宇宙', 1),
#   ('概念股', 1),
#   ('威盛', 1),
#   ('集團', 1),
#   ('宏達電', 1),
#   ('車用', 1)],
#  '產經': [('台灣', 61),
#   ('金管會', 56),
#   ('市場', 31),
#   ('基金', 31),
#   ('金融', 22),
#   ('技術', 19),
#   ('新台幣', 19),
#   ('曝險', 19),
#   ('銀行', 18),
#   ('國家', 18),
#   ('業者', 17),
#   ('員工', 16),
#   ('英國', 16),
#   ('越南', 16),
#   ('產品', 14),
#   ('晶片', 14),
#   ('民眾', 13),
#   ('會議', 13),
#   ('統計', 12),
#   ('經濟', 12),
#   ('推案量', 12),
#   ('莫德納', 11),
#   ('華航', 11),
#   ('專區', 11),
#   ('政府', 11),
#   ('世界', 10),
#   ('電子', 10),
#   ('客機', 10),
#   ('風險', 10),
#   ('措施', 10),
#   ('國科會', 10),
#   ('電信', 10),
#   ('公司', 9),
#   ('產業', 9),
#   ('資訊', 9),
#   ('企業', 9),
#   ('預算', 9),
#   ('央行', 9),
#   ('年增', 9),
#   ('李宜真', 8),
#   ('新聞稿', 8),
#   ('疫情', 8),
#   ('電子報', 8),
#   ('天下', 8),
#   ('信箱', 8),
#   ('格式', 8),
#   ('國際', 8),
#   ('證券', 8),
#   ('政策', 8),
#   ('張子敏', 8),
#   ('福利', 8),
#   ('核心', 8),
#   ('關鍵', 8),
#   ('半導體', 8),
#   ('官員', 8),
#   ('記者會', 8),
#   ('電競', 8),
#   ('液晶', 8),
#   ('軟體', 8),
#   ('競爭', 8),
#   ('全球', 7),
#   ('債券', 7),
#   ('規範', 7),
#   ('公會', 7),
#   ('機制', 7),
#   ('方式', 7),
#   ('保險業', 7),
#   ('顯示器', 7),
#   ('美元', 7),
#   ('雲端', 7),
#   ('大哥大', 7),
#   ('頻段', 7),
#   ('唐邦正', 7),
#   ('比率', 6),
#   ('金額', 6),
#   ('制度', 6),
#   ('意見', 6),
#   ('財政', 6),
#   ('中央', 6),
#   ('稅收', 6),
#   ('債務', 6),
#   ('成長率', 6),
#   ('整體', 6),
#   ('海外', 6),
#   ('客戶', 6),
#   ('總局', 6),
#   ('指數', 6),
#   ('平台', 6),
#   ('問題', 6),
#   ('中國', 6),
#   ('不鏽鋼', 6),
#   ('合併案', 6),
#   ('西門子', 6),
#   ('聯電', 6),
#   ('總經理', 5),
#   ('商業', 5),
#   ('科技', 5),
#   ('美國', 5),
#   ('波音', 5),
#   ('成本', 5),
#   ('環境', 5),
#   ('副局長', 5),
#   ('個股', 5),
#   ('階段', 5),
#   ('計畫', 5),
#   ('集團', 5),
#   ('架構', 5),
#   ('代表', 5),
#   ('委員', 5),
#   ('委員會', 5),
#   ('供應鏈', 5),
#   ('財政部', 5),
#   ('情事', 5),
#   ('數字', 5),
#   ('集邦', 5),
#   ('通膨', 5),
#   ('需求', 5),
#   ('時間', 5),
#   ('資源', 5),
#   ('國內', 5),
#   ('工業', 5),
#   ('聯盟', 5),
#   ('楊金龍', 5),
#   ('價格', 5),
#   ('低資費', 5),
#   ('頻譜', 5),
#   ('住展', 5),
#   ('散裝船', 5),
#   ('有限公司', 4),
#   ('類型', 4),
#   ('疾病', 4),
#   ('機構', 4),
#   ('方案', 4),
#   ('網路', 4),
#   ('觀測站', 4),
#   ('草案', 4),
#   ('等級', 4),
#   ('目標', 4),
#   ('指標', 4),
#   ('證期局', 4),
#   ('規模', 4),
#   ('證交所', 4),
#   ('金控', 4),
#   ('金融業', 4),
#   ('持股', 4),
#   ('莊琇媛', 4),
#   ('程序', 4),
#   ('辦法', 4),
#   ('立法院', 4),
#   ('法規', 4),
#   ('缺口', 4),
#   ('年度', 4),
#   ('歲入', 4),
#   ('稅課', 4),
#   ('收入', 4),
#   ('資料', 4),
#   ('數據', 4),
#   ('歐洲', 4),
#   ('消費者', 4),
#   ('原因', 4),
#   ('面板', 4),
#   ('金融防', 4),
#   ('期貨', 4),
#   ('案例', 4),
#   ('方面', 4),
#   ('議題', 4),
#   ('韓國', 4),
#   ('利益', 4),
#   ('股價', 4),
#   ('台股', 4),
#   ('外匯', 4),
#   ('房市', 4),
#   ('燁聯', 4),
#   ('鋼廠', 4),
#   ('供給量', 4),
#   ('產業署', 4),
#   ('系統', 4),
#   ('聽證會', 4),
#   ('副總經理', 4),
#   ('何世昌', 4),
#   ('船舶', 4),
#   ('中航', 4),
#   ('鐵礦砂', 4),
#   ('設計', 4),
#   ('股份', 3),
#   ('業務', 3),
#   ('日本', 3),
#   ('澳洲', 3),
#   ('子公司', 3),
#   ('COVID-19', 3),
#   ('角色', 3),
#   ('行銷', 3),
#   ('策略', 3),
#   ('能力', 3),
#   ('訂單', 3),
#   ('說明書', 3),
#   ('收益', 3),
#   ('家數', 3),
#   ('時程', 3),
#   ('部門', 3)],
#  '娛樂': [('媽媽', 16),
#   ('電影', 16),
#   ('節目', 15),
#   ('紀曉君', 14),
#   ('角色', 13),
#   ('戰爭', 10),
#   ('老師', 9),
#   ('許瑋甯', 9),
#   ('市場', 8),
#   ('公司', 7),
#   ('廖家儀', 7),
#   ('豪門', 7),
#   ('袁惟仁', 7),
#   ('吳慷仁', 7),
#   ('姚坤君', 6),
#   ('陳文茜', 6),
#   ('台東', 5),
#   ('歌曲', 5),
#   ('台灣', 5),
#   ('世界', 5),
#   ('林煥鈞', 5),
#   ('活動', 5),
#   ('澤倫斯基', 5),
#   ('烏克蘭', 5),
#   ('酷力歐', 5),
#   ('演員', 4),
#   ('月亮', 4),
#   ('媒體', 4),
#   ('女兒', 4),
#   ('孩子', 4),
#   ('公視', 4),
#   ('金馬', 4),
#   ('執委會', 4),
#   ('窄路', 4),
#   ('微塵', 4),
#   ('羅巧倫', 4),
#   ('陳仙梅', 4),
#   ('內容', 4),
#   ('事業', 4),
#   ('人氣', 4),
#   ('戲劇', 4),
#   ('遊戲', 4),
#   ('票數', 4),
#   ('臉書', 4),
#   ('總統', 4),
#   ('社會', 4),
#   ('記者', 4),
#   ('酷力', 4),
#   ('歌手', 3),
#   ('導演', 3),
#   ('王小棣', 3),
#   ('小棣', 3),
#   ('生活', 3),
#   ('名單', 3),
#   ('主角', 3),
#   ('系列', 3),
#   ('阿斯頓', 3),
#   ('馬丁', 3),
#   ('女星', 3),
#   ('豬腳', 3),
#   ('老公', 3),
#   ('電子報', 3),
#   ('天下', 3),
#   ('電子', 3),
#   ('信箱', 3),
#   ('格式', 3),
#   ('成員', 3),
#   ('粉絲', 3),
#   ('藝人', 3),
#   ('電視', 3),
#   ('典禮', 3),
#   ('喜劇', 3),
#   ('俄烏', 3),
#   ('長期', 3),
#   ('網友', 3),
#   ('小胖', 3),
#   ('功課', 2),
#   ('張耀仁', 2),
#   ('支票', 2),
#   ('胡德夫', 2),
#   ('大學', 2),
#   ('家人', 2),
#   ('劇情', 2),
#   ('挑戰', 2),
#   ('金馬獎', 2),
#   ('規定', 2),
#   ('香港', 2),
#   ('佳士得', 2),
#   ('跑車', 2),
#   ('法新社', 2),
#   ('物件', 2),
#   ('八點檔', 2),
#   ('市井', 2),
#   ('現實', 2),
#   ('國中', 2),
#   ('水餃', 2),
#   ('黃雪琴', 2),
#   ('觀眾', 2),
#   ('選秀', 2),
#   ('原子', 2),
#   ('少年', 2),
#   ('心聲', 2),
#   ('林佳辰', 2),
#   ('周子翔', 2),
#   ('李哲言', 2),
#   ('人物', 2),
#   ('行為', 2),
#   ('金鐘獎', 2),
#   ('民眾', 2),
#   ('火神', 2),
#   ('眼淚', 2),
#   ('初選', 2),
#   ('作品', 2),
#   ('決選', 2),
#   ('過程', 2),
#   ('風險', 2),
#   ('軍隊', 2),
#   ('安多利', 2),
#   ('影片', 2),
#   ('生命', 2),
#   ('辦法', 2),
#   ('訊息', 2),
#   ('情況', 2),
#   ('敏迪', 2),
#   ('合照', 2),
#   ('紀寶如', 2),
#   ('當地', 2),
#   ('老家', 2),
#   ('蔡琴', 2),
#   ('同事', 2),
#   ('狀態', 2),
#   ('林晨曦', 2),
#   ('高中', 2),
#   ('賈靜雯', 2),
#   ('戲碼', 2),
#   ('肢體', 2),
#   ('波希', 2),
#   ('友人', 2),
#   ('加州', 2),
#   ('葛萊美獎', 2),
#   ('專輯', 2),
#   ('茁劇場', 1),
#   ('情侶', 1),
#   ('冤家', 1),
#   ('曝戲', 1),
#   ('葛盈瑄', 1),
#   ('母親', 1),
#   ('茶館', 1),
#   ('茶錢', 1),
#   ('服務生', 1),
#   ('燒酒雞', 1),
#   ('貴客', 1),
#   ('表舅', 1),
#   ('叔公', 1),
#   ('現場', 1),
#   ('淡江', 1),
#   ('心防', 1),
#   ('畫面', 1),
#   ('台詞', 1),
#   ('做法', 1),
#   ('名常', 1),
#   ('兒子', 1),
#   ('天兵', 1),
#   ('面前', 1),
#   ('神經', 1),
#   ('要求', 1),
#   ('台視', 1),
#   ('中華', 1),
#   ('電信', 1),
#   ('官網', 1),
#   ('範疇', 1),
#   ('資格', 1),
#   ('張繼聰', 1),
#   ('袁澧林', 1),
#   ('黃衍仁', 1),
#   ('音樂', 1),
#   ('生死', 1),
#   ('複製品', 1),
#   ('價格', 1),
#   ('拍賣會', 1),
#   ('上述', 1),
#   ('所得', 1),
#   ('新台幣', 1),
#   ('進款', 1),
#   ('DB5', 1),
#   ('大燈', 1),
#   ('機槍', 1),
#   ('道具', 1),
#   ('英國', 1),
#   ('特技車', 1),
#   ('汽車', 1),
#   ('服裝', 1),
#   ('配件', 1),
#   ('民視', 1),
#   ('小販', 1),
#   ('長疤', 1),
#   ('情同', 1),
#   ('姐妹', 1),
#   ('同學', 1),
#   ('命運', 1)],
#  '生活': [('台灣', 38),
#   ('疫苗', 25),
#   ('電子', 22),
#   ('教官', 17),
#   ('業者', 16),
#   ('民眾', 15),
#   ('信箱', 13),
#   ('公司', 12),
#   ('疫情', 12),
#   ('學校', 12),
#   ('號碼', 12),
#   ('發票', 11),
#   ('台北', 10),
#   ('中心', 9),
#   ('交通部', 9),
#   ('世界', 9),
#   ('政府', 9),
#   ('航空', 9),
#   ('子宮頸癌', 9),
#   ('學生', 9),
#   ('鄭英傑', 9),
#   ('遠通', 9),
#   ('桃機', 8),
#   ('旅客', 8),
#   ('措施', 8),
#   ('國際', 8),
#   ('電子報', 8),
#   ('天下', 8),
#   ('格式', 8),
#   ('事項', 8),
#   ('美國', 8),
#   ('遠洋', 8),
#   ('漁業', 8),
#   ('氣象局', 8),
#   ('機場', 7),
#   ('結果', 7),
#   ('獎金', 7),
#   ('新加坡', 7),
#   ('時間', 7),
#   ('台南', 7),
#   ('校園', 7),
#   ('黃恩鴻', 7),
#   ('電商', 7),
#   ('星宇', 7),
#   ('設施', 6),
#   ('邊境', 6),
#   ('階段', 6),
#   ('新台幣', 6),
#   ('方式', 6),
#   ('派彩', 6),
#   ('獎號', 6),
#   ('台彩', 6),
#   ('辦事處', 6),
#   ('嘉義', 6),
#   ('生活', 6),
#   ('資料', 6),
#   ('特教', 6),
#   ('電收', 6),
#   ('雲端', 6),
#   ('郵件', 6),
#   ('國稅局', 6),
#   ('手機', 6),
#   ('人員', 5),
#   ('范孝倫', 5),
#   ('作業', 5),
#   ('人次', 5),
#   ('觀光局', 5),
#   ('病毒', 5),
#   ('中央社', 5),
#   ('五分車', 5),
#   ('清單', 5),
#   ('新聞稿', 5),
#   ('澎湖', 5),
#   ('體溫', 5),
#   ('天氣', 5),
#   ('夕陽', 5),
#   ('街道', 5),
#   ('高溫', 5),
#   ('校車', 5),
#   ('通知', 5),
#   ('地區', 5),
#   ('航機', 5),
#   ('居家', 4),
#   ('動線', 4),
#   ('商業', 4),
#   ('總經理', 4),
#   ('工程', 4),
#   ('政策', 4),
#   ('期間', 4),
#   ('星彩', 4),
#   ('記者', 4),
#   ('特色', 4),
#   ('漁獲', 4),
#   ('漁業署', 4),
#   ('人權', 4),
#   ('行動', 4),
#   ('權益', 4),
#   ('病變', 4),
#   ('航線', 4),
#   ('台南市', 4),
#   ('遊客', 4),
#   ('柯建銘', 4),
#   ('工作', 4),
#   ('中央', 4),
#   ('接種率', 4),
#   ('嬰幼兒', 4),
#   ('氣象', 4),
#   ('位置', 4),
#   ('交通', 4),
#   ('高雄市', 4),
#   ('張永昌', 4),
#   ('領袖', 4),
#   ('載具', 4),
#   ('財政部', 4),
#   ('平台', 4),
#   ('衛福部', 3),
#   ('桃園', 3),
#   ('單位', 3),
#   ('國境', 3),
#   ('計程車', 3),
#   ('司機', 3),
#   ('規定', 3),
#   ('師生', 3),
#   ('頭獎', 3),
#   ('貳獎', 3),
#   ('馬來西亞', 3),
#   ('細節', 3),
#   ('冠狀', 3),
#   ('疾病', 3),
#   ('周士弼', 3),
#   ('高雄', 3),
#   ('蒜頭', 3),
#   ('糖廠', 3),
#   ('台糖', 3),
#   ('情形', 3),
#   ('路線', 3),
#   ('勞工部', 3),
#   ('童工', 3),
#   ('貨品', 3),
#   ('計畫', 3),
#   ('船員', 3),
#   ('全球', 3),
#   ('企業', 3),
#   ('社會', 3),
#   ('影響', 3),
#   ('機制', 3),
#   ('部會', 3),
#   ('COVID-19', 3),
#   ('抹片', 3),
#   ('數據', 3),
#   ('癌症', 3),
#   ('麗娜輪', 3),
#   ('航港局', 3),
#   ('馬公港', 3),
#   ('郭貞慧', 3),
#   ('教育部', 3),
#   ('大專', 3),
#   ('吳林輝', 3),
#   ('部隊', 3),
#   ('王必勝', 3),
#   ('莫德納', 3),
#   ('世代', 3),
#   ('西區', 3),
#   ('機會', 3),
#   ('台東', 3),
#   ('溫差', 3),
#   ('駕駛', 3),
#   ('特教生', 3),
#   ('國道', 3),
#   ('智慧', 3),
#   ('評審團', 3),
#   ('勞務', 3),
#   ('統一發票', 3),
#   ('東北', 3),
#   ('陣雨', 3),
#   ('海面', 3),
#   ('設計', 3),
#   ('殼套組', 3),
#   ('狀況', 2),
#   ('金額', 2),
#   ('蘇貞昌', 2),
#   ('人數', 2),
#   ('商店', 2),
#   ('周邊', 2),
#   ('正彩', 2),
#   ('威力彩', 2),
#   ('症狀', 2),
#   ('主任', 2),
#   ('鄭智鴻', 2),
#   ('消費者', 2),
#   ('行程', 2),
#   ('方案', 2),
#   ('意願', 2),
#   ('吉隆坡', 2),
#   ('產品', 2),
#   ('音樂', 2),
#   ('旅展', 2),
#   ('台灣館', 2),
#   ('雙鐵', 2),
#   ('高鐵站', 2)],
#  '國際': [('俄羅斯', 55),
#   ('日本', 33),
#   ('烏克蘭', 32),
#   ('美國', 31),
#   ('北溪', 30),
#   ('管線', 30),
#   ('德國', 28),
#   ('飛彈', 27),
#   ('中國', 27),
#   ('芬蘭', 26),
#   ('北韓', 24),
#   ('國家', 23),
#   ('英國', 23),
#   ('戰機', 22),
#   ('天然氣', 20),
#   ('俄國', 20),
#   ('政府', 18),
#   ('南韓', 16),
#   ('推特', 16),
#   ('國際', 15),
#   ('歐洲', 15),
#   ('伊朗', 15),
#   ('歐盟', 13),
#   ('空軍', 13),
#   ('喇嘛', 12),
#   ('颶風', 12),
#   ('官員', 12),
#   ('區域', 12),
#   ('瑞典', 12),
#   ('事件', 12),
#   ('彈道', 11),
#   ('當局', 11),
#   ('總統', 11),
#   ('行動', 11),
#   ('聲明', 11),
#   ('達賴', 11),
#   ('全球', 11),
#   ('佛州', 11),
#   ('記者', 11),
#   ('柯維立', 10),
#   ('地區', 10),
#   ('丹麥', 10),
#   ('勃恩斯', 10),
#   ('賀錦麗', 9),
#   ('台海', 9),
#   ('艦艇', 9),
#   ('伊恩', 9),
#   ('夥伴', 9),
#   ('波羅的海', 9),
#   ('艾米尼', 9),
#   ('關係', 9),
#   ('行為', 8),
#   ('軍演', 8),
#   ('基礎', 8),
#   ('軍事', 8),
#   ('海岸', 8),
#   ('邊境', 8),
#   ('公司', 8),
#   ('亞洲', 8),
#   ('蒲亭', 8),
#   ('莫斯科', 8),
#   ('克里姆林宮', 8),
#   ('政策', 8),
#   ('颱風', 8),
#   ('印度', 8),
#   ('馬克宏', 8),
#   ('短程', 7),
#   ('世界', 7),
#   ('台灣', 7),
#   ('小時', 7),
#   ('防衛隊', 7),
#   ('路透社', 7),
#   ('印太', 7),
#   ('原因', 7),
#   ('穆哈瑪迪', 7),
#   ('兒童', 7),
#   ('公民', 7),
#   ('洩漏點', 7),
#   ('聯合國', 6),
#   ('基地', 6),
#   ('中俄', 6),
#   ('太平洋', 6),
#   ('行政', 6),
#   ('活動', 6),
#   ('噶廈', 6),
#   ('北京', 6),
#   ('附近', 6),
#   ('民眾', 6),
#   ('外交', 6),
#   ('新加坡', 6),
#   ('影響', 6),
#   ('組織', 6),
#   ('1號', 6),
#   ('2號', 6),
#   ('證據', 6),
#   ('氣體', 6),
#   ('俄方', 6),
#   ('設施', 6),
#   ('占領區', 6),
#   ('培斯科夫', 6),
#   ('航空', 6),
#   ('婦女', 6),
#   ('動議', 6),
#   ('海域', 5),
#   ('數據', 5),
#   ('新聞', 5),
#   ('電子報', 5),
#   ('周邊', 5),
#   ('藏人', 5),
#   ('中央', 5),
#   ('最高法院', 5),
#   ('議會', 5),
#   ('政治', 5),
#   ('法新社', 5),
#   ('經濟', 5),
#   ('能源', 5),
#   ('問題', 5),
#   ('計畫', 5),
#   ('波蘭', 5),
#   ('價格', 5),
#   ('推文', 5),
#   ('部隊', 5),
#   ('發言人', 5),
#   ('儀式', 5),
#   ('版圖', 5),
#   ('華府', 5),
#   ('俄軍', 5),
#   ('方案', 5),
#   ('禁令', 5),
#   ('哈維斯托', 5),
#   ('簽證', 5),
#   ('百里', 5),
#   ('內容', 5),
#   ('廣告', 5),
#   ('參謀', 4),
#   ('本部', 4),
#   ('高度', 4),
#   ('射程', 4),
#   ('情報', 4),
#   ('能力', 4),
#   ('脈動', 4),
#   ('電子', 4),
#   ('信箱', 4),
#   ('格式', 4),
#   ('方式', 4),
#   ('議題', 4),
#   ('自衛隊', 4),
#   ('幕僚長', 4),
#   ('立場', 4),
#   ('活佛', 4),
#   ('官方', 4),
#   ('人民', 4),
#   ('期間', 4),
#   ('演講', 4),
#   ('總理', 4),
#   ('外交部長', 4),
#   ('戰爭', 4),
#   ('能源署', 4),
#   ('位置', 4),
#   ('北約', 4),
#   ('照片', 4),
#   ('報導', 4),
#   ('領土', 4),
#   ('戰事', 4),
#   ('軍方', 4),
#   ('品牌', 4),
#   ('語言', 4),
#   ('大使', 4),
#   ('遊客', 4),
#   ('F-2', 4),
#   ('訓練', 4),
#   ('格哈茲', 4),
#   ('中將', 4),
#   ('性行為', 4),
#   ('聯盟', 4),
#   ('法國', 4),
#   ('國民', 4),
#   ('憲法', 4),
#   ('平壤', 3),
#   ('資訊', 3),
#   ('辦公室', 3),
#   ('會議', 3),
#   ('措施', 3),
#   ('副總統', 3),
#   ('尹錫悅', 3),
#   ('防衛省', 3),
#   ('海軍', 3),
#   ('東海', 3),
#   ('國防部', 3),
#   ('驅逐艦', 3),
#   ('日本海', 3),
#   ('北海道', 3),
#   ('軍艦', 3),
#   ('時間', 3),
#   ('部門', 3),
#   ('佛教', 3),
#   ('宗教', 3),
#   ('情況', 3),
#   ('外國', 3),
#   ('人員', 3)],
#  '社會': [('警方', 34),
#   ('參選人', 22),
#   ('選民', 21),
#   ('林智堅', 19),
#   ('里長', 18),
#   ('民眾', 17),
#   ('樁腳', 17),
#   ('現金', 15),
#   ('法院', 15),
#   ('嘉義市', 14),
#   ('檢方', 13),
#   ('地檢署', 12),
#   ('林秉樞', 12),
#   ('警察局', 12),
#   ('地方', 11),
#   ('高嘉瑜', 11),
#   ('酒精', 11),
#   ('警察', 10),
#   ('機關', 10),
#   ('論文', 10),
#   ('余正煌', 10),
#   ('嘉義', 9),
#   ('調查官', 9),
#   ('碩士', 9),
#   ('男子', 8),
#   ('新台幣', 8),
#   ('一審', 8),
#   ('期間', 8),
#   ('世界', 8),
#   ('電子報', 8),
#   ('天下', 8),
#   ('電子', 8),
#   ('信箱', 8),
#   ('格式', 8),
#   ('車輛', 8),
#   ('路段', 8),
#   ('李朝卿', 8),
#   ('刑法', 7),
#   ('台灣', 7),
#   ('徒刑', 7),
#   ('原因', 7),
#   ('議員', 7),
#   ('顏政德', 7),
#   ('陳政忠', 7),
#   ('台北', 7),
#   ('陳男', 7),
#   ('受刑人', 7),
#   ('林男', 6),
#   ('台北市', 6),
#   ('股票', 6),
#   ('規定', 6),
#   ('學位', 6),
#   ('臉書', 6),
#   ('土地', 5),
#   ('家屬', 5),
#   ('市議員', 5),
#   ('檢調', 5),
#   ('罪嫌', 5),
#   ('照片', 5),
#   ('法官', 5),
#   ('律師', 5),
#   ('人員', 5),
#   ('高院', 5),
#   ('機車', 5),
#   ('政府', 5),
#   ('車主', 5),
#   ('分局', 5),
#   ('國道', 5),
#   ('事故', 5),
#   ('現場', 5),
#   ('台大', 5),
#   ('獅潭鄉', 5),
#   ('刑期', 5),
#   ('楊男', 5),
#   ('明德', 5),
#   ('貨車', 5),
#   ('媒體', 4),
#   ('西區', 4),
#   ('調查站', 4),
#   ('住處', 4),
#   ('婦人', 4),
#   ('新北', 4),
#   ('法庭', 4),
#   ('警消', 4),
#   ('女子', 4),
#   ('畫面', 4),
#   ('公費', 4),
#   ('助理', 4),
#   ('最高法院', 4),
#   ('新竹', 4),
#   ('宏福', 4),
#   ('說明書', 4),
#   ('台南市', 4),
#   ('貼紙', 4),
#   ('市長', 4),
#   ('選舉', 4),
#   ('委員會', 4),
#   ('資料', 4),
#   ('苗栗縣', 4),
#   ('台中', 4),
#   ('高分院', 4),
#   ('楊植斗', 4),
#   ('通訊', 4),
#   ('證明書', 4),
#   ('日期', 4),
#   ('林信吾', 4),
#   ('名義', 4),
#   ('毀損罪', 3),
#   ('員警', 3),
#   ('過程', 3),
#   ('調查局', 3),
#   ('行政', 3),
#   ('當地', 3),
#   ('女廁', 3),
#   ('廁所', 3),
#   ('新竹市', 3),
#   ('條例', 3),
#   ('有期徒刑', 3),
#   ('建設', 3),
#   ('案件', 3),
#   ('車身', 3),
#   ('巡邏車', 3),
#   ('字樣', 3),
#   ('聯結車', 3),
#   ('車道', 3),
#   ('新聞', 3),
#   ('刑事', 3),
#   ('程序', 3),
#   ('縣長', 3),
#   ('工程', 3),
#   ('回扣案', 3),
#   ('社團', 3),
#   ('國家', 3),
#   ('周玉蔻', 3),
#   ('電視台', 3),
#   ('大門', 3),
#   ('中正', 3),
#   ('綠色', 3),
#   ('當事人', 3),
#   ('江振亨', 3),
#   ('仙山', 3),
#   ('登山客', 3),
#   ('金門縣', 3),
#   ('名字', 3),
#   ('鄉親', 3),
#   ('吉安', 2),
#   ('蔡姓', 2),
#   ('農牧', 2),
#   ('用地', 2),
#   ('墳墓', 2),
#   ('蔡男', 2),
#   ('警分局', 2),
#   ('蘇金章', 2),
#   ('林姓', 2),
#   ('柯姓', 2),
#   ('文書', 2),
#   ('祕密', 2),
#   ('靈堂', 2),
#   ('名譽', 2),
#   ('行為', 2),
#   ('私刑', 2),
#   ('刑度', 2),
#   ('精神', 2),
#   ('嘉檢', 2),
#   ('里民', 2),
#   ('龍山寺', 2),
#   ('意外', 2),
#   ('鍾姓', 2),
#   ('字條', 2),
#   ('內容', 2),
#   ('死者', 2),
#   ('監視器', 2),
#   ('姪子', 2),
#   ('事用法', 2),
#   ('違誤', 2),
#   ('被告', 2),
#   ('更四審', 2),
#   ('證交法', 2),
#   ('所得', 2),
#   ('交易', 2),
#   ('有價證券', 2),
#   ('台南', 2),
#   ('美食', 2),
#   ('文字', 2),
#   ('字體', 2),
#   ('新聞稿', 2),
#   ('網站', 2),
#   ('情況', 2),
#   ('形象', 2),
#   ('大隊', 2),
#   ('1號', 2),
#   ('北向', 2),
#   ('右後輪', 2),
#   ('中線', 2),
#   ('公路', 2),
#   ('大林', 2),
#   ('醫院', 2),
#   ('分隊', 2),
#   ('用路人', 2),
#   ('事件', 2)],
#  '文化': [('台灣', 56),
#   ('文化', 32),
#   ('電影', 20),
#   ('藝術', 18),
#   ('水道', 17),
#   ('青年', 14),
#   ('世界', 14),
#   ('台北', 14),
#   ('博物館', 13),
#   ('聖保羅', 13),
#   ('國際', 12),
#   ('廖瓊枝', 12),
#   ('司長', 12),
#   ('陳三五娘', 11),
#   ('故事', 11),
#   ('美國', 11),
#   ('巴西', 11),
#   ('雲門', 11),
#   ('設計師', 10),
#   ('疫情', 10),
#   ('中心', 10),
#   ('音樂會', 10),
#   ('劇場', 10),
#   ('設計', 9),
#   ('電子報', 9),
#   ('天下', 9),
#   ('電子', 9),
#   ('信箱', 9),
#   ('格式', 9),
#   ('人生', 9),
#   ('導演', 9),
#   ('劇團', 9),
#   ('大學', 9),
#   ('青春', 8),
#   ('歌仔戲', 8),
#   ('音樂', 8),
#   ('地點', 8),
#   ('國家', 8),
#   ('文化部', 8),
#   ('觀眾', 8),
#   ('小說', 8),
#   ('形象展', 8),
#   ('朴子', 8),
#   ('團隊', 7),
#   ('產業', 7),
#   ('民眾', 7),
#   ('影像', 7),
#   ('記者會', 7),
#   ('花園', 7),
#   ('舞台', 7),
#   ('計畫', 7),
#   ('新聞稿', 7),
#   ('拉赫瑪尼諾夫', 7),
#   ('歷史', 6),
#   ('展區', 6),
#   ('紀錄', 6),
#   ('戲曲', 6),
#   ('台南', 6),
#   ('藝博', 6),
#   ('原住民', 6),
#   ('漫畫', 6),
#   ('朋友', 6),
#   ('現場', 6),
#   ('女神', 6),
#   ('鋼琴', 6),
#   ('年曆', 6),
#   ('電影展', 6),
#   ('規劃', 6),
#   ('高雄', 5),
#   ('陳其邁', 5),
#   ('城市', 5),
#   ('主題', 5),
#   ('活動', 5),
#   ('特展', 5),
#   ('遊戲', 5),
#   ('畫廊', 5),
#   ('協會', 5),
#   ('戲劇', 5),
#   ('演員', 5),
#   ('湯姆漢克斯', 5),
#   ('政策', 5),
#   ('張正傑', 5),
#   ('輪椅族', 5),
#   ('黃騰輝', 5),
#   ('謝如欣', 5),
#   ('影展', 5),
#   ('新作', 5),
#   ('設計展', 4),
#   ('高雄市', 4),
#   ('政府', 4),
#   ('市長', 4),
#   ('期間', 4),
#   ('科技', 4),
#   ('概念', 4),
#   ('內容', 4),
#   ('展商', 4),
#   ('空間', 4),
#   ('冠狀', 4),
#   ('病毒', 4),
#   ('疾病', 4),
#   ('李存勗', 4),
#   ('台灣陣', 4),
#   ('文創', 4),
#   ('吳曜宇', 4),
#   ('小調', 4),
#   ('協奏曲', 4),
#   ('經典', 4),
#   ('秘密', 4),
#   ('林宏義', 4),
#   ('李永得', 4),
#   ('戲劇團', 4),
#   ('節目', 4),
#   ('作品', 4),
#   ('代表', 3),
#   ('才華', 3),
#   ('高雄港', 3),
#   ('建設', 3),
#   ('中島', 3),
#   ('李小平', 3),
#   ('陳三五', 3),
#   ('情節', 3),
#   ('方式', 3),
#   ('角色', 3),
#   ('記憶', 3),
#   ('台南市', 3),
#   ('文化局', 3),
#   ('古蹟', 3),
#   ('系列', 3),
#   ('園區', 3),
#   ('葉澤山', 3),
#   ('環境', 3),
#   ('模式', 3),
#   ('張逸羣', 3),
#   ('專區', 3),
#   ('優伶', 3),
#   ('天子', 3),
#   ('主角', 3),
#   ('編劇', 3),
#   ('人物', 3),
#   ('劇情', 3),
#   ('影帝', 3),
#   ('時間', 3),
#   ('文總', 3),
#   ('傳統', 3),
#   ('外貿', 3),
#   ('榕樹', 3),
#   ('廣場', 3),
#   ('世界級', 3),
#   ('鋼琴家', 3),
#   ('網站', 3),
#   ('學院', 3),
#   ('嘉藝', 3),
#   ('聚落', 3),
#   ('頭君', 3),
#   ('機台', 3),
#   ('許有仁', 3),
#   ('策展', 3),
#   ('時代', 3),
#   ('交響樂團', 3),
#   ('馬斯里夫', 3),
#   ('大賽', 3),
#   ('玫瑰', 3),
#   ('畫作', 3),
#   ('旅途', 3),
#   ('草根性', 3),
#   ('視野', 3),
#   ('莫子儀', 3),
#   ('影人', 3),
#   ('委員', 3),
#   ('麥洛', 3),
#   ('開幕片', 3),
#   ('趙德胤', 3),
#   ('幕後', 3),
#   ('資源', 3),
#   ('副司長', 3),
#   ('明華園', 3),
#   ('總團', 3),
#   ('木偶', 3),
#   ('青設', 2),
#   ('夜泊', 2),
#   ('商會', 2),
#   ('世代', 2),
#   ('創意', 2),
#   ('青年局', 2),
#   ('棧五庫', 2),
#   ('貨物', 2),
#   ('吞吐量', 2),
#   ('蓬萊', 2),
#   ('商港區', 2),
#   ('經濟', 2),
#   ('張以理', 2),
#   ('時尚', 2),
#   ('柯志恩', 2),
#   ('成果', 2),
#   ('媒體', 2),
#   ('對話', 2),
#   ('身段', 2),
#   ('張孟逸', 2),
#   ('社群', 2),
#   ('劇本', 2)],
#  '兩岸': [('中國', 73),
#   ('國家', 27),
#   ('疫情', 26),
#   ('政策', 26),
#   ('人民', 25),
#   ('兩岸', 22),
#   ('關係', 20),
#   ('住房', 18),
#   ('政府', 18),
#   ('美元', 18),
#   ('人員', 17),
#   ('中共', 17),
#   ('匯率', 17),
#   ('許智峯', 17),
#   ('核酸', 16),
#   ('香港', 16),
#   ('人民幣', 15),
#   ('安倍', 15),
#   ('謠言', 15),
#   ('大陸', 14),
#   ('銀行', 14),
#   ('市場', 14),
#   ('利率', 13),
#   ('邱垂正', 13),
#   ('日本', 13),
#   ('官方', 12),
#   ('陸委會', 12),
#   ('世界', 12),
#   ('外交', 12),
#   ('措施', 11),
#   ('法庭', 11),
#   ('健康碼', 11),
#   ('中華民國', 10),
#   ('貨幣', 10),
#   ('經濟', 10),
#   ('工作', 9),
#   ('會議', 9),
#   ('社會', 9),
#   ('萬鋼', 9),
#   ('利益', 9),
#   ('機制', 8),
#   ('中央', 8),
#   ('民眾', 8),
#   ('階段性', 8),
#   ('當地', 8),
#   ('小三通', 8),
#   ('共識', 8),
#   ('國葬', 8),
#   ('指數', 8),
#   ('胡錫進', 8),
#   ('期間', 7),
#   ('委員會', 7),
#   ('症狀', 7),
#   ('地區', 7),
#   ('政治', 7),
#   ('專項', 7),
#   ('馬朝旭', 7),
#   ('風險', 6),
#   ('微博', 6),
#   ('貸款', 6),
#   ('下限', 6),
#   ('需求', 6),
#   ('商品', 6),
#   ('城市', 6),
#   ('上述', 6),
#   ('領域', 6),
#   ('台灣', 6),
#   ('憲法', 6),
#   ('通膨', 6),
#   ('民生', 6),
#   ('天津', 6),
#   ('國務院', 5),
#   ('網友', 5),
#   ('媒體', 5),
#   ('信貸', 5),
#   ('央行', 5),
#   ('房地產', 5),
#   ('價格', 5),
#   ('房貸', 5),
#   ('專家', 5),
#   ('發言人', 5),
#   ('電子報', 5),
#   ('天下', 5),
#   ('電子', 5),
#   ('信箱', 5),
#   ('格式', 5),
#   ('記者會', 5),
#   ('因素', 5),
#   ('當局', 5),
#   ('北京', 5),
#   ('壓力', 5),
#   ('邦交', 5),
#   ('習近平', 5),
#   ('時代', 5),
#   ('代表', 5),
#   ('晉三', 5),
#   ('病例', 5),
#   ('陸家嘴', 5),
#   ('本土', 5),
#   ('訊息', 5),
#   ('報告', 5),
#   ('靜態', 5),
#   ('網路', 5),
#   ('行動', 5),
#   ('平台', 5),
#   ('標籤', 5),
#   ('陽性', 5),
#   ('官員', 4),
#   ('居家', 4),
#   ('外鎖門', 4),
#   ('方式', 4),
#   ('地方', 4),
#   ('小時', 4),
#   ('COVID-19', 4),
#   ('要求', 4),
#   ('基礎', 4),
#   ('新聞', 4),
#   ('部門', 4),
#   ('剛性', 4),
#   ('原則', 4),
#   ('範圍', 4),
#   ('環境', 4),
#   ('整體', 4),
#   ('陸方', 4),
#   ('情況', 4),
#   ('單位', 4),
#   ('權益', 4),
#   ('總統', 4),
#   ('中華', 4),
#   ('共和國', 4),
#   ('消費者', 4),
#   ('中方', 4),
#   ('首相', 4),
#   ('外交部', 4),
#   ('汪文斌', 4),
#   ('領導人', 4),
#   ('東京', 4),
#   ('儀式', 4),
#   ('衛生', 4),
#   ('區域', 4),
#   ('員工', 4),
#   ('陰性', 4),
#   ('立法會', 4),
#   ('議員', 4),
#   ('海外', 4),
#   ('法院', 4),
#   ('司法', 4),
#   ('林卓廷', 4),
#   ('衝突', 4),
#   ('事件', 4),
#   ('物價', 4),
#   ('文章', 4),
#   ('老胡', 4),
#   ('作用', 4),
#   ('標記', 4),
#   ('樣本', 4),
#   ('黑龍江', 4),
#   ('負評', 3),
#   ('居民', 3),
#   ('上海', 3),
#   ('患者', 3),
#   ('生命', 3),
#   ('評論', 3),
#   ('城市政府', 3),
#   ('官網', 3),
#   ('工具箱', 3),
#   ('商業性', 3),
#   ('規定', 3),
#   ('水準', 3),
#   ('報導', 3),
#   ('重點', 3),
#   ('貓熊', 3),
#   ('台北', 3),
#   ('動物園', 3),
#   ('需要', 3),
#   ('機關', 3),
#   ('金馬', 3),
#   ('落差', 3),
#   ('時機', 3),
#   ('對岸', 3),
#   ('條例', 3),
#   ('法令', 3),
#   ('事務', 3),
#   ('馬英九', 3),
#   ('國內', 3),
#   ('各界', 3),
#   ('主權', 3),
#   ('力度', 3),
#   ('融資', 3),
#   ('主席', 3),
#   ('招待會', 3),
#   ('貢獻', 3),
#   ('政協', 3),
#   ('副主席', 3),
#   ('鐵路', 3),
#   ('冠狀', 3),
#   ('病毒', 3),
#   ('疾病', 3),
#   ('短期', 3),
#   ('公眾號', 3)],
#  '全部': [('台灣', 273),
#   ('中國', 127),
#   ('國家', 106),
#   ('世界', 97),
#   ('民眾', 89),
#   ('國際', 87),
#   ('電子', 87),
#   ('美國', 86),
#   ('政府', 79),
#   ('政策', 69),
#   ('市場', 68),
#   ('疫情', 66),
#   ('信箱', 64),
#   ('新台幣', 64),
#   ('金管會', 63),
#   ('日本', 61),
#   ('電子報', 60),
#   ('格式', 60),
#   ('俄羅斯', 59),
#   ('天下', 56),
#   ('公司', 53),
#   ('英國', 50),
#   ('台北', 49),
#   ('指數', 48),
#   ('人員', 45),
#   ('關係', 43),
#   ('全球', 43),
#   ('措施', 41),
#   ('方式', 41),
#   ('時間', 41),
#   ('烏克蘭', 40),
#   ('台股', 40),
#   ('少年', 39),
#   ('經濟', 38),
#   ('會議', 38),
#   ('銀行', 38),
#   ('金融', 38),
#   ('警方', 38),
#   ('中心', 36),
#   ('社會', 36),
#   ('電影', 36),
#   ('人民', 35),
#   ('文化', 35),
#   ('聯盟', 35),
#   ('新聞稿', 35),
#   ('期間', 35),
#   ('產業', 34),
#   ('業者', 34),
#   ('基金', 34),
#   ('法院', 33),
#   ('歐洲', 33),
#   ('參選人', 32),
#   ('網路', 30),
#   ('總統', 30),
#   ('記者會', 30),
#   ('北溪', 30),
#   ('管線', 30),
#   ('記者', 29),
#   ('中央', 29),
#   ('內容', 29),
#   ('疫苗', 29),
#   ('平台', 29),
#   ('德國', 29),
#   ('代表', 28),
#   ('媒體', 28),
#   ('考試', 28),
#   ('飛彈', 28),
#   ('戰機', 28),
#   ('美元', 28),
#   ('區域', 27),
#   ('地區', 27),
#   ('官員', 27),
#   ('事件', 27),
#   ('兩岸', 26),
#   ('問題', 26),
#   ('行動', 26),
#   ('匯率', 26),
#   ('芬蘭', 26),
#   ('資訊', 25),
#   ('警察', 25),
#   ('台積電', 25),
#   ('台南', 24),
#   ('北韓', 24),
#   ('產品', 23),
#   ('蓬佩奧', 23),
#   ('風險', 23),
#   ('工作', 23),
#   ('委員會', 23),
#   ('情況', 23),
#   ('地方', 23),
#   ('央行', 23),
#   ('技術', 22),
#   ('節目', 22),
#   ('立法院', 22),
#   ('網站', 22),
#   ('規定', 22),
#   ('活動', 22),
#   ('空軍', 22),
#   ('價格', 22),
#   ('科技', 22),
#   ('外資', 22),
#   ('角色', 22),
#   ('官方', 22),
#   ('需求', 21),
#   ('憲法', 21),
#   ('臉書', 21),
#   ('機制', 21),
#   ('計畫', 21),
#   ('員工', 21),
#   ('香港', 21),
#   ('天然氣', 21),
#   ('選民', 21),
#   ('系統', 20),
#   ('企業', 20),
#   ('程序', 20),
#   ('機關', 20),
#   ('目標', 20),
#   ('原因', 20),
#   ('教官', 20),
#   ('當地', 20),
#   ('公民', 20),
#   ('病毒', 20),
#   ('疾病', 20),
#   ('股價', 20),
#   ('現金', 20),
#   ('俄國', 20),
#   ('中共', 19),
#   ('現場', 19),
#   ('關鍵', 19),
#   ('司法', 19),
#   ('資料', 19),
#   ('小時', 19),
#   ('壓力', 19),
#   ('環境', 19),
#   ('外交', 19),
#   ('投信', 19),
#   ('曝險', 19),
#   ('林智堅', 19),
#   ('南韓', 18),
#   ('高雄', 18),
#   ('邊境', 18),
#   ('條例', 18),
#   ('事項', 18),
#   ('推特', 18),
#   ('國內', 18),
#   ('大學', 18),
#   ('安倍', 18),
#   ('統計', 18),
#   ('當局', 18),
#   ('單位', 18),
#   ('終場', 18),
#   ('越南', 18),
#   ('里長', 18),
#   ('藝術', 18),
#   ('住房', 18),
#   ('COVID-19', 17),
#   ('行為', 17),
#   ('韓國', 17),
#   ('基礎', 17),
#   ('晶片', 17),
#   ('條文', 17),
#   ('媽媽', 17),
#   ('試題', 17),
#   ('中華民國', 17),
#   ('機會', 17),
#   ('觀眾', 17),
#   ('航空', 17),
#   ('海外', 17),
#   ('核酸', 17),
#   ('股市', 17),
#   ('客戶', 17),
#   ('嘉義', 17),
#   ('樁腳', 17),
#   ('水道', 17),
#   ('許智峯', 17),
#   ('外交部', 16),
#   ('法律', 16),
#   ('半導體', 16),
#   ('中央社', 16),
#   ('共識', 16),
#   ('團隊', 16),
#   ('運動', 16),
#   ('設施', 16),
#   ('紀錄', 16),
#   ('戰爭', 16),
#   ('遊戲', 16),
#   ('中華', 16),
#   ('冠狀', 16),
#   ('球員', 16),
#   ('年增', 16),
#   ('淨值', 16),
#   ('利率', 16),
#   ('新加坡', 16),
#   ('人民幣', 16),
#   ('設計', 16),
#   ('嘉義市', 16),
#   ('規模', 15),
#   ('資源', 15),
#   ('台海', 15),
#   ('陸委會', 15)]}

# %%
# Here is the function. We will use it for drawing in django website
def get_category_topword(cate, topkeys = 10):
    wf_pairs = data[cate][0:topkeys]
    words = [w for w, f in wf_pairs]
    freqs = [f for w, f in wf_pairs]
    chart_data = {
        "category": cate,
        "labels": words,
        "values": freqs}
    return chart_data, wf_pairs

# %%
get_category_topword('政治', 3)
# Out:
# ({'category': '政治', 'labels': ['台灣', '少年', '考試'], 'values': [71, 36, 28]},
#  [('台灣', 71), ('少年', 36), ('考試', 28)])

# %% [markdown]
# ## Django API for draw the chart of top keywords

# %%
# POST: csrf_exempt should be used
# 指定這一支程式忽略csrf驗證
from django.views.decorators.csrf import csrf_exempt
@csrf_exempt
def api_get_cate_topword(request):
    cate = request.POST.get('news_category')
    #cate = request.POST['news_category'] # this command is also works.
    topkeys = request.POST.get('topkeys')
    topkeys = int(topkeys)
    print(cate, topkeys)

    chart_data, wf_pairs = get_category_topword(cate, topkeys)
    response = {'chart_data': chart_data,
         'wf_pairs': wf_pairs,
         }
    print(response)
    return JsonResponse(response)
